# %% [markdown]
# use file cox-parsed_7214rows_with_labels.csv
# It contains predicted and ground truth used in propublica
# compute the fairness metrics by compas_screening_date

# %% [markdown]
# # get all time stamps

# %%
# First, install the autoreload extension
# %load_ext autoreload
# Set autoreload to automatically reload modules
# %autoreload 2
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from algorithm import CR_0_20240118 as CR
from algorithm import CR_baseline_0_20240118 as CR_baseline

# %% [markdown]
# # read data

# %%
data = pd.read_csv('../../data/compas/preprocessed/cox-parsed_7214rows_with_labels_sorted_by_dates.csv')

# %%
data[:30]
# Out:
#        id                name      first        last compas_screening_date  \
# 0   10686     martin martinez     martin    martinez            2013-01-01
# 1    5084       regina battle     regina      battle            2013-01-01
# 2     604      devaughn brown   devaughn       brown            2013-01-01
# 3      16     kortney coleman    kortney     coleman            2013-01-01
# 4    9339    william mulligan    william    mulligan            2013-01-01
# 5    1196       kevin kendall      kevin     kendall            2013-01-01
# 6    5193        dorean nairn     dorean       nairn            2013-01-01
# 7    5507    patwayne walters   patwayne     walters            2013-01-01
# 8     820    terrance holland   terrance     holland            2013-01-01
# 9    1704        susana colon     susana       colon            2013-01-01
# 10   9234  stephanie mclaurin  stephanie    mclaurin            2013-01-01
# 11   3456        daniel dayes     daniel       dayes            2013-01-01
# 12    446       mikerlie debe   mikerlie        debe            2013-01-01
# 13   1257       michael davis    michael       davis            2013-01-01
# 14   1321        freddie bush    freddie        bush            2013-01-02
# 15   1734      vanessa albino    vanessa      albino            2013-01-02
# 16   5948         gary schwab       gary      schwab            2013-01-02
# 17    806   mckenzie reijonen   mckenzie    reijonen            2013-01-02
# 18   6957       akeine banner     akeine      banner            2013-01-02
# 19   3863        jules canuet      jules      canuet            2013-01-02
# 20   4641    elizabeth maddox  elizabeth      maddox            2013-01-02
# 21   3768  natacha cherenfant    natacha  cherenfant            2013-01-02
# 22  10706     demetrius weeks  demetrius       weeks            2013-01-02
# 23   6111   veronica talavera   veronica    talavera            2013-01-02
# 24    210       taquawn davis    taquawn       davis            2013-01-02
# 25   8863      victor morales     victor     morales            2013-01-02
# 26   2566      melvin stewart     melvin     stewart            2013-01-02
# 27    317           jenay doe      jenay         doe            2013-01-02
# 28   2109         louis sells      louis       sells            2013-01-02
# 29   2352        evience aime    evience        aime            2013-01-02
#
#        sex         dob  age          age_cat              race  ...  \
# 0     Male  1980-01-06   36          25 - 45         Caucasian  ...
# 1   Female  1988-06-28   27          25 - 45  African-American  ...
# 2     Male  1993-07-25   22     Less than 25  African-American  ...
# 3   Female  1978-08-22   37          25 - 45         Caucasian  ...
# 4     Male  1986-10-25   29          25 - 45         Caucasian  ...
# 5     Male  1984-09-16   31          25 - 45         Caucasian  ...
# 6   Female  1979-11-15   36          25 - 45  African-American  ...
# 7     Male  1972-10-24   43          25 - 45             Other  ...
# 8     Male  1984-01-11   32          25 - 45          Hispanic  ...
# 9   Female  1966-10-17   49  Greater than 45         Caucasian  ...
# 10  Female  1985-06-29   30          25 - 45  African-American  ...
# 11    Male  1994-08-25   21     Less than 25  African-American  ...
# 12  Female  1994-10-09   21     Less than 25  African-American  ...
# 13    Male  1993-11-08   22     Less than 25  African-American  ...
# 14    Male  1967-07-31   48  Greater than 45  African-American  ...
# 15  Female  1974-07-20   41          25 - 45         Caucasian  ...
# 16    Male  1955-10-01   60  Greater than 45         Caucasian  ...
# 17    Male  1991-07-18   24     Less than 25         Caucasian  ...
# 18    Male  1988-11-10   27          25 - 45  African-American  ...
# 19    Male  1989-10-17   26          25 - 45         Caucasian  ...
# 20  Female  1981-02-20   35          25 - 45         Caucasian  ...
# 21  Female  1980-03-01   36          25 - 45  African-American  ...
# 22    Male  1973-11-02   42          25 - 45  African-American  ...
# 23  Female  1967-10-28   48  Greater than 45  African-American  ...
# 24    Male  1984-01-26   32          25 - 45  African-American  ...
# 25    Male  1984-10-22   31          25 - 45          Hispanic  ...
# 26    Male  1989-02-28   27          25 - 45  African-American  ...
# 27  Female  1987-10-07   28          25 - 45  African-American  ...
# 28    Male  1989-05-17   26          25 - 45         Caucasian  ...
# 29    Male  1970-12-06   45  Greater than 45  African-American  ...
#
#     in_custody  out_custody  priors_count.1  start   end  event predicted  \
# 0   2013-01-01   2013-02-06               0     36  1186      0         0
# 1          NaN          NaN               0      0  1186      0         0
# 2   2013-12-30   2014-01-10               0     21   363      0         1
# 3   2013-01-01   2013-01-02               0      1  1186      0         0
# 4   2013-01-04   2013-01-05               1      0     2      1         0
# 5   2013-01-01   2013-01-06               0      5  1186      0         0
# 6   2013-03-16   2013-03-16               5      1    74      0         1
# 7          NaN          NaN               2      0  1186      0         0
# 8   2013-01-01   2013-01-02              20      1  1186      0         1
# 9   2013-05-08   2013-05-08               0      0   127      0         0
# 10         NaN          NaN               0      0  1186      0         0
# 11  2013-01-01   2013-01-02               1      1   748      1         1
# 12  2013-01-01   2013-01-02               0      1  1186      0         1
# 13  2013-01-29   2013-01-30               1      0    28      1         1
# 14         NaN          NaN               5      0   389      1         0
# 15         NaN          NaN               0      0  1185      0         0
# 16         NaN          NaN               1      0  1185      0         0
# 17  2013-01-01   2013-01-16               0     14  1185      0         0
# 18  2013-01-01   2013-01-10               3      8   360      1         1
# 19  2013-01-01   2013-01-02               0      0  1185      0         0
# 20  2013-01-01   2013-01-02               1      0  1185      0         0
# 21  2013-01-02   2013-01-02               1      0  1185      0         0
# 22  2013-01-02   2013-01-09               0      7  1185      0         1
# 23  2013-01-02   2013-01-02               0      0  1185      0         0
# 24  2014-02-19   2014-02-27               3      7   413      0         1
# 25  2013-02-26   2013-09-21               5     37    55      0         1
# 26  2014-01-07   2014-01-29               2      0   370      0         1
# 27  2015-06-10   2015-08-28               1     38   889      0         1
# 28  2013-01-02   2013-01-02               0      0  1185      0         1
# 29  2013-01-01   2013-01-02               0      0  1185      0         0
#
#    ground_truth window_key new_window
# 0             0       None       True
# 1             0       None       True
# 2             1       None       True
# 3             0       None       True
# 4             1       None       True
# 5             0       None       True
# 6             1       None       True
# 7             0       None       True
# 8             0       None       True
# 9             1       None       True
# 10            0       None       True
# 11            0       None       True
# 12            0       None       True
# 13            1       None       True
# 14            1       None       True
# 15            0       None       True
# 16            0       None       True
# 17            0       None       True
# 18            1       None       True
# 19            0       None       True
# 20            0       None       True
# 21            0       None       True
# 22            0       None       True
# 23            0       None       True
# 24            1       None       True
# 25            1       None       True
# 26            0       None       True
# 27            0       None       True
# 28            0       None       True
# 29            0       None       True
#
# [30 rows x 56 columns]

# %%
# get distribution of compas_screening_date
data['compas_screening_date'] = pd.to_datetime(data['compas_screening_date'])
data['compas_screening_date'].hist()
# Out:
# <Axes: >

# %%
# # get the month and year of the date
# data['month'] = data['compas_screening_date'].apply(lambda x: x.month)
# data['year'] = data['compas_screening_date'].apply(lambda x: x.year)
# print(data['month'][:4])

# %%
# # get data with in the first month
# data_first_month = data[data['compas_screening_date'] < '2013-08-01']

# %% [markdown]
# # process time series

# %%
# use CR to monitor tpr of different races over time
# a time window is a month

# Function to compute the time window key (e.g., year-month for 'month' windows)
def compute_time_window_key(row, window_type):
    print(window_type)
    if window_type == 'year':
        return row.year
    elif window_type == 'month':
        return f"{row.year}-{row.month}"
    elif window_type == 'week':
        return f"{row.year}-{row.week}"
    elif window_type == 'day':
        return f"{row.year}-{row.month}-{row.day}"

def belong_to_group(row, group):
    for key in group.keys():
        if row[key] != group[key]:
            return False
    return True

def monitorCR(timed_data, date_column, time_window_str, monitored_groups, threshold, alpha):

    units = {'month': 'M', 'year': 'Y', 'day': 'D', 'week': 'W'}
    number, unit = time_window_str.split()
    unit = units[unit]  # Convert to pandas offset alias
    
    
    # Apply the function to compute the window key for each row
    timed_data['window_key'] = timed_data[date_column].apply(compute_time_window_key, args=(unit,))
    print(timed_data['window_key'][:10])
    # Determine the start of a new window
    timed_data['new_window'] = timed_data['window_key'] != timed_data['window_key'].shift(1)
    
    DFMonitor = CR.DF_CR(monitored_groups, alpha, threshold)
    DFMonitor.print()
    first_row_index = timed_data.index[0]  # Get the index of the first row
    counters = [0] * len(monitored_groups)
    total_counter = 0
    first_window_processed = False
    
    def process_each_tuple(row, DFMonitor, first_row_index):
        nonlocal counters
        nonlocal total_counter
        nonlocal first_window_processed
        # print(row['race'])
        if row.name == first_row_index:  # initialization
            total_counter += 1
            for group in monitored_groups:
                if belong_to_group(row, group):
                    counters[monitored_groups.index(group)] += 1
        elif row['new_window']:  # new window
            DFMonitor.print()
            if not first_window_processed:
                uf = [True if counters[i]/total_counter > threshold else False for i in range(len(counters))]
                delta = [abs(threshold * total_counter - counters[i]) * alpha for i in range(len(counters))]
                DFMonitor.initialization(uf, delta)
                first_window_processed = True
            else:
                DFMonitor.new_window()
            DFMonitor.insert(row)
        return 
    
    timed_data.apply(process_each_tuple, axis=1, args=(DFMonitor, first_row_index,))

# %%
monitored_groups = [{"race": 'African-American'}, {"race": 'Caucasian'}]
alpha = 0.5
threshold = 0.1
monitorCR(data, "compas_screening_date", "1 month", monitored_groups, threshold, alpha)
# Out:
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# 0    None
# 1    None
# 2    None
# 3    None
# 4    None
# 5    None
# 6    None
# 7    None
# 8    None
# 9    None
# Name: window_key, dtype: object
# uf []
# delta []
# Caucasian
# African-American
# uf []
# delta []
# African-American
# uf [False, True]
# delta [0.9500000000000001, 0.55]
# Caucasian
# uf [False, True]
# delta [1.375, 0.375]
# Caucasian
# uf [False, False]
# delta [0.5875, 0.7125]
# Caucasian
# uf [False, False]
# delta [0.19375, 1.25625]
# African-American
# uf [True, False]
# delta [0.0031250000000000028, 1.5281250000000002]
# Other
# uf [False, False]
# delta [0.8984375, 0.6640625000000001]
# Hispanic
# uf [False, False]
# delta [0.34921875, 0.23203125000000005]
# Caucasian
# uf [False, False]
# delta [0.074609375, 0.01601562500000002]
# African-American
# uf [True, False]
# delta [0.0626953125, 0.9080078125000001]
# African-American
# uf [False, False]
# delta [0.86865234375, 0.35400390625]
# African-American
# uf [False, False]
# delta [1.334326171875, 0.077001953125]
# African-American
# uf [False, True]
# delta [1.5671630859375, 0.06149902343750001]
# African-American
# uf [False, True]
# delta [1.6835815429687502, 0.13074951171875002]
# Caucasian
# uf [False, True]
# delta [1.741790771484375, 0.165374755859375]
# Caucasian
# uf [False, False]
# delta [0.7708953857421875, 0.8173126220703125]
# Caucasian
# uf [False, False]
# delta [0.28544769287109373, 1.3086563110351563]
# African-American
# uf [False, False]
# delta [0.04272384643554686, 1.5543281555175783]
# Caucasian
# uf [False, False]
# delta [0.9213619232177734, 0.6771640777587892]
# Caucasian
# uf [False, False]
# delta [0.36068096160888674, 1.2385820388793947]
# African-American
# uf [False, False]
# delta [0.08034048080444336, 1.5192910194396974]
# African-American
# uf [False, False]
# delta [0.9401702404022217, 0.6596455097198487]
# African-American
# uf [False, False]
# delta [1.3700851202011108, 0.22982275485992434]
# African-American
# uf [False, False]
# delta [1.5850425601005553, 0.014911377429962167]
# Hispanic
# uf [False, True]
# delta [1.6925212800502778, 0.09254431128501892]
# African-American
# uf [False, True]
# delta [0.7462606400251389, 0.14627215564250945]
# African-American
# uf [False, True]
# delta [1.2731303200125694, 0.17313607782125473]
# Caucasian
# uf [False, True]
# delta [1.5365651600062846, 0.18656803891062737]
# African-American
# uf [False, False]
# delta [0.6682825800031423, 0.8067159805446863]
# Caucasian
# uf [False, False]
# delta [1.2341412900015711, 0.3033579902723431]
# African-American
# uf [False, False]
# delta [0.5170706450007856, 1.0516789951361716]
# African-American
# uf [False, False]
# delta [1.1585353225003927, 0.4258394975680858]
# African-American
# uf [False, False]
# delta [1.4792676612501965, 0.1129197487840429]
# Caucasian
# uf [False, True]
# delta [1.6396338306250984, 0.043540125607978555]
# Asian
# uf [False, False]
# delta [0.7198169153125492, 0.8782299371960107]
# Other
# uf [False, False]
# delta [0.25990845765627457, 0.3391149685980054]
# African-American
# uf [False, False]
# delta [0.02995422882813728, 0.06955748429900269]
# Caucasian
# uf [False, True]
# delta [0.9149771144140687, 0.06522125785049866]
# Caucasian
# uf [False, False]
# delta [0.3574885572070343, 0.8673893710747507]
# Caucasian
# uf [False, False]
# delta [0.07874427860351715, 1.3336946855373752]
# African-American
# uf [True, False]
# delta [0.06062786069824143, 1.5668473427686878]
# African-American
# uf [False, False]
# delta [0.8696860696508794, 0.6834236713843439]
# African-American
# uf [False, False]
# delta [1.3348430348254396, 0.24171183569217194]
# Other
# uf [False, False]
# delta [1.5674215174127197, 0.020855917846085967]
# African-American
# uf [False, True]
# delta [0.6837107587063599, 0.08957204107695702]
# African-American
# uf [False, True]
# delta [1.24185537935318, 0.1447860205384785]
# African-American
# uf [False, True]
# delta [1.52092768967659, 0.17239301026923926]
# African-American
# uf [False, True]
# delta [1.660463844838295, 0.18619650513461963]
# Caucasian
# uf [False, True]
# delta [1.7302319224191476, 0.19309825256730984]
# Caucasian
# uf [False, False]
# delta [0.7651159612095738, 0.803450873716345]
# Caucasian
# uf [False, False]
# delta [0.2825579806047869, 1.3017254368581725]
# African-American
# uf [False, False]
# delta [0.04127899030239343, 1.5508627184290864]
# Hispanic
# uf [False, False]
# delta [0.9206394951511967, 0.6754313592145432]
# Hispanic
# uf [False, False]
# delta [0.36031974757559837, 0.2377156796072716]
# African-American
# uf [False, False]
# delta [0.08015987378779918, 0.018857839803635798]
# African-American
# uf [False, True]
# delta [0.9400799368938996, 0.0905710800981821]
# African-American
# uf [False, True]
# delta [1.3700399684469498, 0.14528554004909106]
# Caucasian
# uf [False, True]
# delta [1.585019984223475, 0.17264277002454553]
# Hispanic
# uf [False, False]
# delta [0.6925099921117375, 0.8136786149877273]
# African-American
# uf [False, False]
# delta [0.24625499605586873, 0.3068393074938637]
# African-American
# uf [False, False]
# delta [1.0231274980279343, 0.05341965374693183]
# Caucasian
# uf [False, True]
# delta [1.4115637490139672, 0.07329017312653409]
# African-American
# uf [False, False]
# delta [0.6057818745069836, 0.863354913436733]
# Caucasian
# uf [False, False]
# delta [1.2028909372534917, 0.33167745671836646]
# African-American
# uf [False, False]
# delta [0.5014454686267459, 1.0658387283591833]
# Caucasian
# uf [False, False]
# delta [1.150722734313373, 0.43291936417959165]
# African-American
# uf [False, False]
# delta [0.47536136715668653, 1.1164596820897958]
# Hispanic
# uf [False, False]
# delta [1.1376806835783433, 0.45822984104489795]
# African-American
# uf [False, False]
# delta [0.46884034178917167, 0.12911492052244897]
# Caucasian
# uf [False, True]
# delta [1.1344201708945858, 0.03544253973877552]
# African-American
# uf [False, False]
# delta [0.4672100854472929, 0.8822787301306123]
# Other
# uf [False, False]
# delta [1.1336050427236466, 0.3411393650653062]
# African-American
# uf [False, False]
# delta [0.4668025213618233, 0.07056968253265308]
# African-American
# uf [False, True]
# delta [1.1334012606809116, 0.06471515873367346]
# Caucasian
# uf [False, True]
# delta [1.4667006303404557, 0.13235757936683673]
# African-American
# uf [False, False]
# delta [0.6333503151702279, 0.8338212103165816]
# African-American
# uf [False, False]
# delta [1.216675157585114, 0.31691060515829084]
# African-American
# uf [False, False]
# delta [1.508337578792557, 0.05845530257914541]
# Caucasian
# uf [False, True]
# delta [1.6541687893962784, 0.0707723487104273]
# African-American
# uf [False, False]
# delta [0.7270843946981392, 0.8646138256447864]
# African-American
# uf [False, False]
# delta [1.2635421973490697, 0.3323069128223932]
# African-American
# uf [False, False]
# delta [1.5317710986745348, 0.0661534564111966]
# African-American
# uf [False, True]
# delta [1.6658855493372675, 0.0669232717944017]
# Other
# uf [False, True]
# delta [1.7329427746686337, 0.13346163589720086]
# African-American
# uf [False, True]
# delta [0.7664713873343169, 0.16673081794860045]
# African-American
# uf [False, True]
# delta [1.2832356936671585, 0.18336540897430023]
# African-American
# uf [False, True]
# delta [1.5416178468335793, 0.19168270448715014]
# African-American
# uf [False, True]
# delta [1.6708089234167898, 0.19584135224357507]
# African-American
# uf [False, True]
# delta [1.735404461708395, 0.19792067612178754]
# Caucasian
# uf [False, True]
# delta [1.7677022308541974, 0.19896033806089378]
# Caucasian
# uf [False, False]
# delta [0.7838511154270987, 0.8005198309695531]
# African-American
# uf [False, False]
# delta [0.29192555771354933, 1.3002599154847765]
# Caucasian
# uf [False, False]
# delta [1.0459627788567747, 0.5501299577423883]
# Caucasian
# uf [False, False]
# delta [0.42298138942838737, 1.1750649788711942]
# African-American
# uf [False, False]
# delta [0.11149069471419368, 1.4875324894355972]
# African-American
# uf [False, False]
# delta [0.9557453473570968, 0.6437662447177986]
# African-American
# uf [False, False]
# delta [1.3778726736785485, 0.22188312235889932]
# Caucasian
# uf [False, False]
# delta [1.5889363368392742, 0.010941561179449652]
# African-American
# uf [False, False]
# delta [0.6944681684196371, 0.9054707805897249]
# Hispanic
# uf [False, False]
# delta [1.2472340842098186, 0.35273539029486245]
# Other
# uf [False, False]
# delta [0.5236170421049093, 0.07636769514743122]
# Hispanic
# uf [False, True]
# delta [0.16180852105245466, 0.061816152426284396]
# African-American
# uf [True, True]
# delta [0.019095739473772674, 0.1309080762131422]
# African-American
# uf [False, True]
# delta [0.8904521302631137, 0.1654540381065711]
# Caucasian
# uf [False, True]
# delta [1.3452260651315568, 0.18272701905328556]
# African-American
# uf [False, False]
# delta [0.5726130325657784, 0.8086364904733573]
# African-American
# uf [False, False]
# delta [1.1863065162828892, 0.3043182452366786]
# Caucasian
# uf [False, False]
# delta [1.4931532581414446, 0.0521591226183393]
# Caucasian
# uf [False, False]
# delta [0.6465766290707223, 0.9260795613091697]
# Caucasian
# uf [False, False]
# delta [0.22328831453536116, 1.3630397806545849]
# African-American
# uf [False, False]
# delta [0.011644157267680574, 1.5815198903272925]
# Caucasian
# uf [False, False]
# delta [0.9058220786338403, 0.6907599451636462]
# African-American
# uf [False, False]
# delta [0.35291103931692014, 1.245379972581823]
# Caucasian
# uf [False, False]
# delta [1.07645551965846, 0.5226899862909116]
# African-American
# uf [False, False]
# delta [0.43822775982923, 1.1613449931454558]
# African-American
# uf [False, False]
# delta [1.119113879914615, 0.4806724965727279]
# Hispanic
# uf [False, False]
# delta [1.4595569399573076, 0.14033624828636396]
# African-American
# uf [False, True]
# delta [0.6297784699786538, 0.029831875856818027]
# Caucasian
# uf [False, True]
# delta [1.214889234989327, 0.11491593792840901]
# African-American
# uf [False, False]
# delta [0.5074446174946635, 0.8425420310357955]
# Hispanic
# uf [False, False]
# delta [1.1537223087473318, 0.3212710155178977]
# Other
# uf [False, False]
# delta [0.47686115437366594, 0.06063550775894885]
# African-American
# uf [False, True]
# delta [0.13843057718683296, 0.06968224612052558]
# African-American
# uf [False, True]
# delta [0.9692152885934165, 0.1348411230602628]
# African-American
# uf [False, True]
# delta [1.3846076442967084, 0.1674205615301314]
# Caucasian
# uf [False, True]
# delta [1.592303822148354, 0.1837102807650657]
# Other
# uf [False, False]
# delta [0.6961519110741771, 0.8081448596174672]
# African-American
# uf [False, False]
# delta [0.24807595553708853, 0.3040724298087336]
# African-American
# uf [False, False]
# delta [1.0240379777685442, 0.0520362149043668]
# African-American
# uf [False, True]
# delta [1.412018988884272, 0.0739818925478166]
# Hispanic
# uf [False, True]
# delta [1.606009494442136, 0.13699094627390832]
# Hispanic
# uf [False, True]
# delta [0.703004747221068, 0.16849547313695418]
# Caucasian
# uf [False, True]
# delta [0.25150237361053396, 0.1842477365684771]
# Caucasian
# uf [False, False]
# delta [0.025751186805266973, 0.8078761317157614]
# Other
# uf [True, False]
# delta [0.08712440659736652, 1.3039380658578807]
# African-American
# uf [True, False]
# delta [0.14356220329868327, 0.5519690329289404]
# African-American
# uf [False, False]
# delta [0.8282188983506584, 0.1759845164644702]
# Hispanic
# uf [False, True]
# delta [1.3141094491753291, 0.01200774176776491]
# African-American
# uf [False, True]
# delta [0.5570547245876646, 0.10600387088388247]
# African-American
# uf [False, True]
# delta [1.1785273622938324, 0.15300193544194124]
# African-American
# uf [False, True]
# delta [1.4892636811469162, 0.17650096772097063]
# African-American
# uf [False, True]
# delta [1.6446318405734581, 0.18825048386048532]
# African-American
# uf [False, True]
# delta [1.722315920286729, 0.19412524193024266]
# Hispanic
# uf [False, True]
# delta [1.7611579601433647, 0.19706262096512134]
# African-American
# uf [False, True]
# delta [0.7805789800716824, 0.19853131048256067]
# African-American
# uf [False, True]
# delta [1.2902894900358413, 0.19926565524128034]
# Other
# uf [False, True]
# delta [1.5451447450179208, 0.19963282762064016]
# African-American
# uf [False, True]
# delta [0.6725723725089604, 0.1998164138103201]
# African-American
# uf [False, True]
# delta [1.2362861862544803, 0.19990820690516004]
# African-American
# uf [False, True]
# delta [1.5181430931272402, 0.19995410345258002]
# African-American
# uf [False, True]
# delta [1.65907154656362, 0.19997705172629002]
# African-American
# uf [False, True]
# delta [1.72953577328181, 0.19998852586314503]
# Hispanic
# uf [False, True]
# delta [1.7647678866409051, 0.19999426293157252]
# African-American
# uf [False, True]
# delta [0.7823839433204526, 0.19999713146578627]
# Caucasian
# uf [False, True]
# delta [1.2911919716602263, 0.19999856573289315]
# Caucasian
# uf [False, False]
# delta [0.5455959858301132, 0.8000007171335535]
# African-American
# uf [False, False]
# delta [0.17279799291505657, 1.3000003585667768]
# African-American
# uf [False, False]
# delta [0.9863989964575283, 0.5500001792833884]
# African-American
# uf [False, False]
# delta [1.393199498228764, 0.1750000896416942]
# Caucasian
# uf [False, True]
# delta [1.596599749114382, 0.012499955179152908]
# African-American
# uf [False, False]
# delta [0.698299874557191, 0.8937500224104236]
# Caucasian
# uf [False, False]
# delta [1.2491499372785955, 0.3468750112052118]
# Caucasian
# uf [False, False]
# delta [0.5245749686392978, 1.073437505602606]
# African-American
# uf [False, False]
# delta [0.16228748431964887, 1.436718752801303]
# Other
# uf [False, False]
# delta [0.9811437421598245, 0.6183593764006515]
# African-American
# uf [False, False]
# delta [0.3905718710799122, 0.20917968820032576]
# Caucasian
# uf [False, False]
# delta [1.0952859355399562, 0.004589844100162874]
# African-American
# uf [False, False]
# delta [0.44764296776997814, 0.9022949220500814]
# African-American
# uf [False, False]
# delta [1.1238214838849891, 0.3511474610250407]
# Caucasian
# uf [False, False]
# delta [1.4619107419424946, 0.07557373051252034]
# African-American
# uf [False, False]
# delta [0.6309553709712473, 0.9377868652562602]
# African-American
# uf [False, False]
# delta [1.2154776854856237, 0.3688934326281301]
# Caucasian
# uf [False, False]
# delta [1.5077388427428118, 0.08444671631406506]
# African-American
# uf [False, False]
# delta [0.6538694213714059, 0.9422233581570325]
# African-American
# uf [False, False]
# delta [1.226934710685703, 0.3711116790785163]
# Other
# uf [False, False]
# delta [1.5134673553428515, 0.08555583953925813]
# Caucasian
# uf [False, True]
# delta [0.6567336776714258, 0.05722208023037094]
# Asian
# uf [False, False]
# delta [0.22836683883571288, 0.8713889598848146]
# Caucasian
# uf [False, False]
# delta [0.014183419417856433, 0.3356944799424073]
# African-American
# uf [True, False]
# delta [0.09290829029107178, 1.0678472399712038]
# African-American
# uf [False, False]
# delta [0.8535458548544641, 0.4339236199856019]
# Caucasian
# uf [False, False]
# delta [1.326772927427232, 0.11696180999280095]
# African-American
# uf [False, False]
# delta [0.563386463713616, 0.9584809049964005]
# African-American
# uf [False, False]
# delta [1.181693231856808, 0.37924045249820026]
# Caucasian
# uf [False, False]
# delta [1.4908466159284042, 0.08962022624910013]
# African-American
# uf [False, False]
# delta [0.6454233079642021, 0.9448101131245501]
# African-American
# uf [False, False]
# delta [1.222711653982101, 0.37240505656227507]
# African-American
# uf [False, False]
# delta [1.5113558269910505, 0.08620252828113753]
# Hispanic
# uf [False, True]
# delta [1.6556779134955253, 0.05689873585943124]
# Caucasian
# uf [False, True]
# delta [0.7278389567477627, 0.12844936792971562]
# African-American
# uf [False, False]
# delta [0.2639194783738813, 0.8357753160351422]
# Caucasian
# uf [False, False]
# delta [1.0319597391869406, 0.31788765801757113]
# African-American
# uf [False, False]
# delta [0.41597986959347033, 1.0589438290087856]
# African-American
# uf [False, False]
# delta [1.1079899347967352, 0.4294719145043928]
# African-American
# uf [False, False]
# delta [1.4539949673983676, 0.1147359572521964]
# African-American
# uf [False, True]
# delta [1.6269974836991838, 0.042632021373901804]
# African-American
# uf [False, True]
# delta [1.713498741849592, 0.12131601068695091]
# Caucasian
# uf [False, True]
# delta [1.7567493709247959, 0.16065800534347546]
# Caucasian
# uf [False, False]
# delta [0.778374685462398, 0.8196709973282623]
# African-American
# uf [False, False]
# delta [0.28918734273119895, 1.3098354986641312]
# Caucasian
# uf [False, False]
# delta [1.0445936713655994, 0.5549177493320656]
# African-American
# uf [False, False]
# delta [0.42229683568279974, 1.1774588746660328]
# Asian
# uf [False, False]
# delta [1.1111484178414, 0.48872943733301644]
# African-American
# uf [False, False]
# delta [0.4555742089207, 0.1443647186665082]
# African-American
# uf [False, True]
# delta [1.12778710446035, 0.0278176406667459]
# African-American
# uf [False, True]
# delta [1.463893552230175, 0.11390882033337296]
# Caucasian
# uf [False, True]
# delta [1.6319467761150874, 0.1569544101666865]
# African-American
# uf [False, False]
# delta [0.7159733880575437, 0.8215227949166568]
# Caucasian
# uf [False, False]
# delta [1.2579866940287718, 0.3107613974583284]
# African-American
# uf [False, False]
# delta [0.5289933470143859, 1.0553806987291643]
# Caucasian
# uf [False, False]
# delta [1.1644966735071929, 0.42769034936458217]
# Caucasian
# uf [False, False]
# delta [0.48224833675359646, 1.113845174682291]
# Caucasian
# uf [False, False]
# delta [0.14112416837679823, 1.4569225873411455]
# African-American
# uf [True, False]
# delta [0.029437915811600893, 1.628461293670573]
# Caucasian
# uf [False, False]
# delta [0.8852810420941996, 0.7142306468352865]
# Caucasian
# uf [False, False]
# delta [0.34264052104709974, 1.2571153234176433]
# Caucasian
# uf [False, False]
# delta [0.07132026052354987, 1.5285576617088217]
# African-American
# uf [True, False]
# delta [0.06433986973822507, 1.664278830854411]
# African-American
# uf [False, False]
# delta [0.8678300651308875, 0.7321394154272055]
# Caucasian
# uf [False, False]
# delta [1.3339150325654439, 0.2660697077136027]
# African-American
# uf [False, False]
# delta [0.566957516282722, 1.0330348538568015]
# Caucasian
# uf [False, False]
# delta [1.183478758141361, 0.41651742692840077]
# African-American
# uf [False, False]
# delta [0.49173937907068055, 1.1082587134642004]
# African-American
# uf [False, False]
# delta [1.1458696895353402, 0.4541293567321002]
# African-American
# uf [False, False]
# delta [1.47293484476767, 0.1270646783660501]
# Caucasian
# uf [False, True]
# delta [1.6364674223838351, 0.03646766081697496]
# African-American
# uf [False, False]
# delta [0.7182337111919176, 0.8817661695915125]
# Caucasian
# uf [False, False]
# delta [1.2591168555959589, 0.34088308479575624]
# African-American
# uf [False, False]
# delta [0.5295584277979795, 1.0704415423978781]
# Caucasian
# uf [False, False]
# delta [1.1647792138989899, 0.4352207711989391]
# African-American
# uf [False, False]
# delta [0.48238960694949495, 1.1176103855994697]
# African-American
# uf [False, False]
# delta [1.1411948034747474, 0.45880519279973486]
# Hispanic
# uf [False, False]
# delta [1.4705974017373737, 0.12940259639986743]
# Caucasian
# uf [False, True]
# delta [0.6352987008686869, 0.03529870180006629]
# Caucasian
# uf [False, False]
# delta [0.21764935043434344, 0.8823506490999669]
# African-American
# uf [False, False]
# delta [0.008824675217171715, 1.3411753245499836]
# Caucasian
# uf [False, False]
# delta [0.9044123376085859, 0.5705876622749918]
# African-American
# uf [False, False]
# delta [0.3522061688042929, 1.1852938311374959]
# Hispanic
# uf [False, False]
# delta [1.0761030844021464, 0.49264691556874796]
# Caucasian
# uf [False, False]
# delta [0.43805154220107323, 0.14632345778437397]
# Caucasian
# uf [False, False]
# delta [0.11902577110053661, 0.973161728892187]
# Caucasian
# uf [True, False]
# delta [0.0404871144497317, 1.3865808644460935]
# African-American
# uf [True, False]
# delta [0.12024355722486585, 1.5932904322230468]
# African-American
# uf [False, False]
# delta [0.8398782213875671, 0.6966452161115234]
# African-American
# uf [False, False]
# delta [1.3199391106937837, 0.2483226080557617]
# Caucasian
# uf [False, False]
# delta [1.5599695553468917, 0.024161304027880845]
# Caucasian
# uf [False, False]
# delta [0.6799847776734459, 0.9120806520139404]
# African-American
# uf [False, False]
# delta [0.23999238883672294, 1.3560403260069702]
# African-American
# uf [False, False]
# delta [1.0199961944183615, 0.5780201630034851]
# African-American
# uf [False, False]
# delta [1.4099980972091808, 0.18901008150174256]
# Caucasian
# uf [False, True]
# delta [1.6049990486045904, 0.005494959249128725]
# African-American
# uf [False, False]
# delta [0.7024995243022952, 0.8972525203754357]
# African-American
# uf [False, False]
# delta [1.2512497621511476, 0.3486262601877178]
# African-American
# uf [False, False]
# delta [1.525624881075574, 0.0743131300938589]
# African-American
# uf [False, True]
# delta [1.6628124405377869, 0.06284343495307056]
# African-American
# uf [False, True]
# delta [1.7314062202688936, 0.13142171747653528]
# African-American
# uf [False, True]
# delta [1.7657031101344467, 0.16571085873826763]
# African-American
# uf [False, True]
# delta [1.7828515550672233, 0.18285542936913382]
# Hispanic
# uf [False, True]
# delta [1.7914257775336115, 0.19142771468456693]
# Caucasian
# uf [False, True]
# delta [0.7957128887668058, 0.19571385734228347]
# African-American
# uf [False, False]
# delta [0.29785644438340286, 0.8021430713288583]
# African-American
# uf [False, False]
# delta [1.0489282221917016, 0.3010715356644291]
# Hispanic
# uf [False, False]
# delta [1.4244641110958507, 0.050535767832214556]
# Caucasian
# uf [False, True]
# delta [0.6122320555479254, 0.07473211608389273]
# African-American
# uf [False, False]
# delta [0.20611602777396268, 0.8626339419580537]
# Caucasian
# uf [False, False]
# delta [1.0030580138869813, 0.3313169709790268]
# Other
# uf [False, False]
# delta [0.4015290069434907, 1.0656584854895135]
# Caucasian
# uf [False, False]
# delta [0.10076450347174534, 0.43282924274475676]
# Hispanic
# uf [True, False]
# delta [0.049617748264127334, 1.1164146213723785]
# African-American
# uf [True, False]
# delta [0.12480887413206368, 0.45820731068618925]
# Caucasian
# uf [False, False]
# delta [0.8375955629339682, 0.12910365534309462]
# Caucasian
# uf [False, False]
# delta [0.3187977814669841, 0.9645518276715473]
# African-American
# uf [False, False]
# delta [0.059398890733492055, 1.3822759138357736]
# Caucasian
# uf [False, False]
# delta [0.9296994453667461, 0.5911379569178868]
# African-American
# uf [False, False]
# delta [0.364849722683373, 1.1955689784589434]
# Hispanic
# uf [False, False]
# delta [1.0824248613416865, 0.4977844892294717]
# Caucasian
# uf [False, False]
# delta [0.44121243067084326, 0.14889224461473585]
# African-American
# uf [False, False]
# delta [0.12060621533542162, 0.9744461223073679]
# Caucasian
# uf [False, False]
# delta [0.9603031076677109, 0.387223061153684]
# Caucasian
# uf [False, False]
# delta [0.38015155383385546, 1.0936115305768421]
# Caucasian
# uf [False, False]
# delta [0.09007577691692772, 1.446805765288421]
# African-American
# uf [True, False]
# delta [0.05496211154153614, 1.6234028826442106]
# Caucasian
# uf [False, False]
# delta [0.8725189442292319, 0.7117014413221053]
# African-American
# uf [False, False]
# delta [0.33625947211461593, 1.2558507206610527]
# African-American
# uf [False, False]
# delta [1.0681297360573079, 0.5279253603305264]
# African-American
# uf [False, False]
# delta [1.434064868028654, 0.1639626801652632]
# Caucasian
# uf [False, True]
# delta [1.6170324340143272, 0.01801865991736841]
# African-American
# uf [False, False]
# delta [0.7085162170071636, 0.8909906700413158]
# African-American
# uf [False, False]
# delta [1.2542581085035818, 0.3454953350206579]
# Other
# uf [False, False]
# delta [1.527129054251791, 0.07274766751032893]
# African-American
# uf [False, True]
# delta [0.6635645271258955, 0.06362616624483554]
# African-American
# uf [False, True]
# delta [1.2317822635629478, 0.13181308312241777]
# African-American
# uf [False, True]
# delta [1.515891131781474, 0.16590654156120888]
# Caucasian
# uf [False, True]
# delta [1.6579455658907372, 0.18295327078060444]
# African-American
# uf [False, False]
# delta [0.7289727829453686, 0.8085233646096978]
# African-American
# uf [False, False]
# delta [1.2644863914726843, 0.30426168230484885]
# Other
# uf [False, False]
# delta [1.532243195736342, 0.05213084115242442]
# Caucasian
# uf [False, True]
# delta [0.666121597868171, 0.0739345794237878]
# Caucasian
# uf [False, False]
# delta [0.23306079893408552, 0.8630327102881061]
# African-American
# uf [False, False]
# delta [0.016530399467042753, 1.331516355144053]
# African-American
# uf [False, False]
# delta [0.9082651997335214, 0.5657581775720265]
# African-American
# uf [False, False]
# delta [1.3541325998667606, 0.18287908878601325]
# African-American
# uf [False, True]
# delta [1.5770662999333802, 0.00856045560699338]
# Caucasian
# uf [False, True]
# delta [1.6885331499666902, 0.10428022780349669]
# African-American
# uf [False, False]
# delta [0.7442665749833451, 0.8478598860982517]
# Caucasian
# uf [False, False]
# delta [1.2721332874916726, 0.3239299430491258]
# African-American
# uf [False, False]
# delta [0.5360666437458363, 1.061964971524563]
# Caucasian
# uf [False, False]
# delta [1.1680333218729182, 0.4309824857622815]
# African-American
# uf [False, False]
# delta [0.4840166609364591, 1.1154912428811408]
# Caucasian
# uf [False, False]
# delta [1.1420083304682296, 0.4577456214405704]
# Caucasian
# uf [False, False]
# delta [0.4710041652341148, 1.1288728107202852]
# Caucasian
# uf [False, False]
# delta [0.1355020826170574, 1.4644364053601426]
# African-American
# uf [True, False]
# delta [0.032248958691471305, 1.6322182026800713]
# Caucasian
# uf [False, False]
# delta [0.8838755206542643, 0.7161091013400357]
# African-American
# uf [False, False]
# delta [0.3419377603271322, 1.2580545506700178]
# African-American
# uf [False, False]
# delta [1.0709688801635662, 0.5290272753350089]
# Caucasian
# uf [False, False]
# delta [1.4354844400817832, 0.16451363766750446]
# Caucasian
# uf [False, False]
# delta [0.6177422200408916, 0.9822568188337523]
# Caucasian
# uf [False, False]
# delta [0.2088711100204458, 1.391128409416876]
# African-American
# uf [False, False]
# delta [0.0044355550102229, 1.5955642047084382]
# African-American
# uf [False, False]
# delta [0.9022177775051115, 0.6977821023542191]
# African-American
# uf [False, False]
# delta [1.3511088887525557, 0.24889105117710955]
# Hispanic
# uf [False, False]
# delta [1.575554444376278, 0.02444552558855477]
# African-American
# uf [False, True]
# delta [0.687777222188139, 0.08777723720572261]
# African-American
# uf [False, True]
# delta [1.2438886110940695, 0.1438886186028613]
# Caucasian
# uf [False, True]
# delta [1.5219443055470347, 0.17194430930143068]
# African-American
# uf [False, False]
# delta [0.6609721527735174, 0.8140278453492846]
# Caucasian
# uf [False, False]
# delta [1.2304860763867587, 0.30701392267464234]
# African-American
# uf [False, False]
# delta [0.5152430381933794, 1.0535069613373211]
# African-American
# uf [False, False]
# delta [1.1576215190966896, 0.4267534806686606]
# Caucasian
# uf [False, False]
# delta [1.4788107595483448, 0.11337674033433029]
# African-American
# uf [False, False]
# delta [0.6394053797741724, 0.9566883701671651]
# African-American
# uf [False, False]
# delta [1.2197026898870862, 0.3783441850835826]
# African-American
# uf [False, False]
# delta [1.5098513449435431, 0.08917209254179129]
# African-American
# uf [False, True]
# delta [1.6549256724717716, 0.05541395372910436]
# African-American
# uf [False, True]
# delta [1.727462836235886, 0.12770697686455218]
# Caucasian
# uf [False, True]
# delta [1.7637314181179429, 0.1638534884322761]
# African-American
# uf [False, False]
# delta [0.7818657090589715, 0.8180732557838619]
# African-American
# uf [False, False]
# delta [1.2909328545294858, 0.309036627891931]
# African-American
# uf [False, False]
# delta [1.545466427264743, 0.054518313945965485]
# Hispanic
# uf [False, True]
# delta [1.6727332136323714, 0.07274084302701726]
# Other
# uf [False, True]
# delta [0.7363666068161857, 0.13637042151350864]
# African-American
# uf [False, True]
# delta [0.2681833034080928, 0.16818521075675433]
# Caucasian
# uf [False, True]
# delta [1.0340916517040464, 0.18409260537837718]
# African-American
# uf [False, False]
# delta [0.4170458258520232, 0.8079536973108115]
# African-American
# uf [False, False]
# delta [1.1085229129260117, 0.30397684865540575]
# Caucasian
# uf [False, False]
# delta [1.4542614564630059, 0.05198842432770287]
# Caucasian
# uf [False, False]
# delta [0.627130728231503, 0.9259942121638515]
# African-American
# uf [False, False]
# delta [0.21356536411575147, 1.3629971060819257]
# Caucasian
# uf [False, False]
# delta [1.0067826820578758, 0.5814985530409629]
# African-American
# uf [False, False]
# delta [0.4033913410289379, 1.1907492765204815]
# Caucasian
# uf [False, False]
# delta [1.101695670514469, 0.49537463826024075]
# African-American
# uf [False, False]
# delta [0.4508478352572345, 1.1476873191301205]
# African-American
# uf [False, False]
# delta [1.1254239176286172, 0.47384365956506025]
# African-American
# uf [False, False]
# delta [1.4627119588143085, 0.13692182978253012]
# African-American
# uf [False, True]
# delta [1.6313559794071542, 0.031539085108734946]
# Caucasian
# uf [False, True]
# delta [1.7156779897035772, 0.11576954255436747]
# Caucasian
# uf [False, False]
# delta [0.7578389948517886, 0.8421152287228163]
# Hispanic
# uf [False, False]
# delta [0.2789194974258943, 1.3210576143614081]
# African-American
# uf [False, False]
# delta [0.039459748712947135, 0.5605288071807041]
# Caucasian
# uf [False, False]
# delta [0.9197298743564736, 0.18026440359035203]
# African-American
# uf [False, False]
# delta [0.35986493717823675, 0.990132201795176]
# African-American
# uf [False, False]
# delta [1.0799324685891185, 0.395066100897588]
# African-American
# uf [False, False]
# delta [1.4399662342945594, 0.09753305044879398]
# Hispanic
# uf [False, True]
# delta [1.6199831171472798, 0.05123347477560301]
# Caucasian
# uf [False, True]
# delta [0.7099915585736399, 0.12561673738780152]
# Caucasian
# uf [False, False]
# delta [0.25499577928681993, 0.8371916313060993]
# African-American
# uf [False, False]
# delta [0.027497889643409962, 1.3185958156530497]
# Caucasian
# uf [False, False]
# delta [0.913748944821705, 0.5592979078265249]
# African-American
# uf [False, False]
# delta [0.35687447241085246, 1.1796489539132624]
# African-American
# uf [False, False]
# delta [1.0784372362054262, 0.4898244769566312]
# Native American
# uf [False, False]
# delta [1.4392186181027131, 0.1449122384783156]
# African-American
# uf [False, True]
# delta [0.6196093090513566, 0.0275438807608422]
# African-American
# uf [False, True]
# delta [1.2098046545256782, 0.1137719403804211]
# African-American
# uf [False, True]
# delta [1.504902327262839, 0.15688597019021056]
# African-American
# uf [False, True]
# delta [1.6524511636314196, 0.17844298509510528]
# Caucasian
# uf [False, True]
# delta [1.7262255818157097, 0.18922149254755266]
# Caucasian
# uf [False, False]
# delta [0.7631127909078549, 0.8053892537262237]
# Hispanic
# uf [False, False]
# delta [0.2815563954539274, 1.3026946268631119]
# African-American
# uf [False, False]
# delta [0.0407781977269637, 0.551347313431556]
# Caucasian
# uf [False, False]
# delta [0.9203890988634819, 0.17567365671577798]
# African-American
# uf [False, False]
# delta [0.3601945494317409, 0.987836828357889]
# African-American
# uf [False, False]
# delta [1.0800972747158704, 0.39391841417894446]
# Hispanic
# uf [False, False]
# delta [1.4400486373579353, 0.09695920708947223]
# African-American
# uf [False, True]
# delta [0.6200243186789677, 0.05152039645526389]
# African-American
# uf [False, True]
# delta [1.210012159339484, 0.12576019822763196]
# Caucasian
# uf [False, True]
# delta [1.505006079669742, 0.16288009911381598]
# African-American
# uf [False, False]
# delta [0.652503039834871, 0.818559950443092]
# Hispanic
# uf [False, False]
# delta [1.2262515199174355, 0.30927997522154604]
# Other
# uf [False, False]
# delta [0.5131257599587178, 0.054639987610773016]
# African-American
# uf [False, True]
# delta [0.1565628799793589, 0.0726800061946135]
# African-American
# uf [False, True]
# delta [0.9782814399896794, 0.13634000309730676]
# African-American
# uf [False, True]
# delta [1.3891407199948398, 0.1681700015486534]
# African-American
# uf [False, True]
# delta [1.59457035999742, 0.1840850007743267]
# African-American
# uf [False, True]
# delta [1.69728517999871, 0.19204250038716336]
# Other
# uf [False, True]
# delta [1.748642589999355, 0.1960212501935817]
# Other
# uf [False, True]
# delta [0.7743212949996775, 0.19801062509679085]
# African-American
# uf [False, True]
# delta [0.2871606474998387, 0.19900531254839543]
# African-American
# uf [False, True]
# delta [1.0435803237499193, 0.19950265627419772]
# Caucasian
# uf [False, True]
# delta [1.4217901618749598, 0.19975132813709887]
# Caucasian
# uf [False, False]
# delta [0.6108950809374799, 0.8001243359314506]
# African-American
# uf [False, False]
# delta [0.20544754046873995, 1.3000621679657254]
# African-American
# uf [False, False]
# delta [1.00272377023437, 0.5500310839828627]
# Caucasian
# uf [False, False]
# delta [1.401361885117185, 0.17501554199143135]
# Hispanic
# uf [False, False]
# delta [0.6006809425585925, 0.9875077709957157]
# African-American
# uf [False, False]
# delta [0.20034047127929624, 0.39375388549785784]
# African-American
# uf [False, False]
# delta [1.0001702356396482, 0.09687694274892891]
# Other
# uf [False, True]
# delta [1.4000851178198241, 0.05156152862553555]
# African-American
# uf [False, True]
# delta [0.6000425589099121, 0.12578076431276777]
# Caucasian
# uf [False, True]
# delta [1.200021279454956, 0.1628903821563839]
# African-American
# uf [False, False]
# delta [0.5000106397274781, 0.8185548089218081]
# African-American
# uf [False, False]
# delta [1.150005319863739, 0.309277404460904]
# Caucasian
# uf [False, False]
# delta [1.4750026599318695, 0.054638702230452]
# Caucasian
# uf [False, False]
# delta [0.6375013299659348, 0.927319351115226]
# African-American
# uf [False, False]
# delta [0.21875066498296739, 1.3636596755576131]
# Other
# uf [False, False]
# delta [1.0093753324914838, 0.5818298377788066]
# Caucasian
# uf [False, False]
# delta [0.40468766624574193, 0.1909149188894033]
# Caucasian
# uf [False, False]
# delta [0.10234383312287096, 0.9954574594447017]
# African-American
# uf [True, False]
# delta [0.048828083438564526, 1.3977287297223508]
# African-American
# uf [False, False]
# delta [0.8755859582807177, 0.5988643648611754]
# Caucasian
# uf [False, False]
# delta [1.3377929791403589, 0.19943218243058772]
# Hispanic
# uf [False, False]
# delta [0.5688964895701795, 0.9997160912152939]
# Caucasian
# uf [False, False]
# delta [0.18444824478508973, 0.39985804560764693]
# Caucasian
# uf [True, False]
# delta [0.007775877607455142, 1.0999290228038234]
# Caucasian
# uf [True, False]
# delta [0.10388793880372757, 1.4499645114019117]
# Other
# uf [True, False]
# delta [0.15194396940186378, 1.624982255700956]
# Caucasian
# uf [True, False]
# delta [0.1759719847009319, 0.712491127850478]
# African-American
# ...
# Caucasian
# uf [False, True]
# delta [1.7701836451106256, 0.1858091296311951]
# Caucasian
# uf [False, False]
# delta [0.7850918225553128, 0.8070954351844024]
# African-American
# uf [False, False]
# delta [0.2925459112776564, 1.3035477175922012]
# Caucasian
# uf [False, False]
# delta [1.0462729556388282, 0.5517738587961006]
# Caucasian
# uf [False, False]
# delta [0.4231364778194141, 1.1758869293980503]
# Other
# uf [False, False]
# delta [0.11156823890970705, 1.487943464699025]
# Caucasian
# uf [True, False]
# delta [0.04421588054514648, 0.6439717323495125]
# Caucasian
# uf [True, False]
# delta [0.12210794027257324, 1.2219858661747562]
# African-American
# uf [True, False]
# delta [0.16105397013628664, 1.5109929330873781]
# Other
# uf [False, False]
# delta [0.8194730149318568, 0.6554964665436891]
# African-American
# uf [False, False]
# delta [0.3097365074659284, 0.22774823327184454]
# Caucasian
# uf [False, False]
# delta [1.0548682537329643, 0.013874116635922265]
# Caucasian
# uf [False, False]
# delta [0.4274341268664822, 0.9069370583179611]
# African-American
# uf [False, False]
# delta [0.11371706343324109, 1.3534685291589805]
# African-American
# uf [False, False]
# delta [0.9568585317166206, 0.5767342645794903]
# African-American
# uf [False, False]
# delta [1.3784292658583104, 0.18836713228974514]
# African-American
# uf [False, True]
# delta [1.5892146329291552, 0.005816433855127437]
# African-American
# uf [False, True]
# delta [1.6946073164645776, 0.10290821692756372]
# African-American
# uf [False, True]
# delta [1.7473036582322887, 0.15145410846378188]
# Caucasian
# uf [False, True]
# delta [1.7736518291161443, 0.17572705423189094]
# Caucasian
# uf [False, False]
# delta [0.7868259145580722, 0.8121364728840545]
# Caucasian
# uf [False, False]
# delta [0.29341295727903605, 1.3060682364420273]
# Caucasian
# uf [False, False]
# delta [0.04670647863951802, 1.5530341182210137]
# African-American
# uf [True, False]
# delta [0.076646760680241, 1.6765170591105067]
# African-American
# uf [False, False]
# delta [0.8616766196598795, 0.7382585295552534]
# Caucasian
# uf [False, False]
# delta [1.33083830982994, 0.26912926477762666]
# Caucasian
# uf [False, False]
# delta [0.56541915491497, 1.0345646323888134]
# Caucasian
# uf [False, False]
# delta [0.18270957745748498, 1.4172823161944068]
# African-American
# uf [True, False]
# delta [0.008645211271257516, 1.6086411580972033]
# African-American
# uf [False, False]
# delta [0.8956773943643712, 0.7043205790486017]
# African-American
# uf [False, False]
# delta [1.3478386971821856, 0.2521602895243008]
# African-American
# uf [False, False]
# delta [1.573919348591093, 0.026080144762150398]
# Caucasian
# uf [False, True]
# delta [1.6869596742955464, 0.0869599276189248]
# African-American
# uf [False, False]
# delta [0.7434798371477732, 0.8565200361905376]
# Caucasian
# uf [False, False]
# delta [1.2717399185738867, 0.32826001809526884]
# African-American
# uf [False, False]
# delta [0.5358699592869434, 1.0641300090476344]
# African-American
# uf [False, False]
# delta [1.1679349796434717, 0.43206500452381724]
# African-American
# uf [False, False]
# delta [1.4839674898217359, 0.11603250226190862]
# African-American
# uf [False, True]
# delta [1.6419837449108678, 0.0419837488690457]
# Caucasian
# uf [False, True]
# delta [1.7209918724554338, 0.12099187443452286]
# African-American
# uf [False, False]
# delta [0.7604959362277169, 0.8395040627827386]
# African-American
# uf [False, False]
# delta [1.2802479681138585, 0.3197520313913693]
# Caucasian
# uf [False, False]
# delta [1.5401239840569292, 0.05987601569568465]
# African-American
# uf [False, False]
# delta [0.6700619920284646, 0.9299380078478423]
# Caucasian
# uf [False, False]
# delta [1.2350309960142323, 0.3649690039239212]
# African-American
# uf [False, False]
# delta [0.5175154980071162, 1.0824845019619607]
# Caucasian
# uf [False, False]
# delta [1.158757749003558, 0.44124225098098036]
# Caucasian
# uf [False, False]
# delta [0.4793788745017791, 1.1206211254904903]
# Other
# uf [False, False]
# delta [0.13968943725088953, 1.4603105627452453]
# Caucasian
# uf [True, False]
# delta [0.03015528137455524, 0.6301552813726227]
# African-American
# uf [True, False]
# delta [0.11507764068727763, 1.2150776406863113]
# African-American
# uf [False, False]
# delta [0.8424611796563612, 0.5075388203431557]
# African-American
# uf [False, False]
# delta [1.3212305898281806, 0.15376941017157783]
# Caucasian
# uf [False, True]
# delta [1.5606152949140903, 0.02311529491421109]
# Caucasian
# uf [False, False]
# delta [0.6803076474570452, 0.8884423525428945]
# African-American
# uf [False, False]
# delta [0.2401538237285226, 1.3442211762714473]
# Caucasian
# uf [False, False]
# delta [1.0200769118642614, 0.5721105881357237]
# Hispanic
# uf [False, False]
# delta [0.41003845593213073, 1.186055294067862]
# African-American
# uf [False, False]
# delta [0.10501922796606536, 0.493027647033931]
# Hispanic
# uf [False, False]
# delta [0.9525096139830327, 0.14651382351696549]
# Asian
# uf [False, True]
# delta [0.37625480699151637, 0.026743088241517263]
# African-American
# uf [False, True]
# delta [0.08812740349575818, 0.11337154412075864]
# Caucasian
# uf [False, True]
# delta [0.9440637017478791, 0.1566857720603793]
# African-American
# uf [False, False]
# delta [0.37203185087393953, 0.8216571139698103]
# Caucasian
# uf [False, False]
# delta [1.08601592543697, 0.3108285569849052]
# Hispanic
# uf [False, False]
# delta [0.44300796271848497, 1.0554142784924525]
# African-American
# uf [False, False]
# delta [0.12150398135924248, 0.4277071392462263]
# African-American
# uf [False, False]
# delta [0.9607519906796212, 0.11385356962311313]
# Hispanic
# uf [False, True]
# delta [1.3803759953398107, 0.04307321518844344]
# Caucasian
# uf [False, True]
# delta [0.5901879976699054, 0.12153660759422172]
# Caucasian
# uf [False, False]
# delta [0.19509399883495268, 0.8392316962028892]
# Caucasian
# uf [True, False]
# delta [0.002453000582523665, 1.3196158481014446]
# African-American
# uf [True, False]
# delta [0.10122650029126185, 1.5598079240507223]
# Caucasian
# uf [False, False]
# delta [0.8493867498543691, 0.6799039620253612]
# African-American
# uf [False, False]
# delta [0.32469337492718453, 1.2399519810126807]
# African-American
# uf [False, False]
# delta [1.0623466874635923, 0.5199759905063404]
# African-American
# uf [False, False]
# delta [1.4311733437317962, 0.15998799525317017]
# Other
# uf [False, True]
# delta [1.615586671865898, 0.02000600237341492]
# African-American
# uf [False, True]
# delta [0.707793335932949, 0.11000300118670747]
# African-American
# uf [False, True]
# delta [1.2538966679664745, 0.15500150059335374]
# Caucasian
# uf [False, True]
# delta [1.5269483339832373, 0.1775007502966769]
# Hispanic
# uf [False, False]
# delta [0.6634741669916187, 0.8112496248516616]
# Caucasian
# uf [False, False]
# delta [0.23173708349580932, 0.30562481242583084]
# African-American
# uf [False, False]
# delta [0.015868541747904655, 1.0528124062129154]
# Caucasian
# uf [False, False]
# delta [0.9079342708739524, 0.4264062031064577]
# Caucasian
# uf [False, False]
# delta [0.3539671354369762, 1.1132031015532289]
# Caucasian
# uf [False, False]
# delta [0.0769835677184881, 1.4566015507766146]
# Caucasian
# uf [True, False]
# delta [0.06150821614075595, 1.6283007753883072]
# African-American
# uf [True, False]
# delta [0.130754108070378, 1.7141503876941537]
# African-American
# uf [False, False]
# delta [0.834622945964811, 0.7570751938470769]
# African-American
# uf [False, False]
# delta [1.3173114729824056, 0.2785375969235384]
# Caucasian
# uf [False, False]
# delta [1.5586557364912028, 0.0392687984617692]
# African-American
# uf [False, False]
# delta [0.6793278682456014, 0.9196343992308846]
# African-American
# uf [False, False]
# delta [1.2396639341228006, 0.35981719961544234]
# African-American
# uf [False, False]
# delta [1.5198319670614002, 0.07990859980772116]
# African-American
# uf [False, True]
# delta [1.6599159835307002, 0.06004570009613942]
# African-American
# uf [False, True]
# delta [1.72995799176535, 0.1300228500480697]
# Caucasian
# uf [False, True]
# delta [1.7649789958826752, 0.16501142502403487]
# African-American
# uf [False, False]
# delta [0.7824894979413376, 0.8174942874879826]
# African-American
# uf [False, False]
# delta [1.2912447489706689, 0.30874714374399126]
# Caucasian
# uf [False, False]
# delta [1.5456223744853346, 0.054373571871995624]
# African-American
# uf [False, False]
# delta [0.6728111872426673, 0.9271867859359978]
# Caucasian
# uf [False, False]
# delta [1.2364055936213336, 0.36359339296799886]
# Caucasian
# uf [False, False]
# delta [0.5182027968106668, 1.0817966964839996]
# Caucasian
# uf [False, False]
# delta [0.1591013984053334, 1.440898348242]
# Caucasian
# uf [True, False]
# delta [0.0204493007973333, 1.620449174121]
# African-American
# uf [True, False]
# delta [0.11022465039866666, 1.7102245870605]
# African-American
# uf [False, False]
# delta [0.8448876748006667, 0.75511229353025]
# African-American
# uf [False, False]
# delta [1.3224438374003333, 0.27755614676512497]
# African-American
# uf [False, False]
# delta [1.5612219187001668, 0.03877807338256248]
# African-American
# uf [False, True]
# delta [1.6806109593500835, 0.08061096330871877]
# African-American
# uf [False, True]
# delta [1.7403054796750417, 0.14030548165435938]
# Caucasian
# uf [False, True]
# delta [1.770152739837521, 0.17015274082717968]
# African-American
# uf [False, False]
# delta [0.7850763699187605, 0.8149236295864102]
# Caucasian
# uf [False, False]
# delta [1.2925381849593802, 0.3074618147932051]
# African-American
# uf [False, False]
# delta [0.5462690924796901, 1.0537309073966026]
# African-American
# uf [False, False]
# delta [1.173134546239845, 0.4268654536983013]
# Caucasian
# uf [False, False]
# delta [1.4865672731199226, 0.11343272684915065]
# African-American
# uf [False, False]
# delta [0.6432836365599613, 0.9567163634245753]
# Caucasian
# uf [False, False]
# delta [1.2216418182799806, 0.37835818171228763]
# Hispanic
# uf [False, False]
# delta [0.5108209091399903, 1.0891790908561438]
# Caucasian
# uf [False, False]
# delta [0.15541045456999517, 0.44458954542807194]
# Caucasian
# uf [True, False]
# delta [0.022294772715002423, 1.122294772714036]
# African-American
# uf [True, False]
# delta [0.11114738635750121, 1.461147386357018]
# African-American
# uf [False, False]
# delta [0.8444263068212494, 0.630573693178509]
# Caucasian
# uf [False, False]
# delta [1.3222131534106247, 0.21528684658925448]
# African-American
# uf [False, False]
# delta [0.5611065767053124, 1.0076434232946272]
# Hispanic
# uf [False, False]
# delta [1.1805532883526562, 0.4038217116473136]
# African-American
# uf [False, False]
# delta [0.4902766441763281, 0.1019108558236568]
# Caucasian
# uf [False, True]
# delta [1.1451383220881641, 0.049044572088171604]
# Caucasian
# uf [False, False]
# delta [0.4725691610440821, 0.8754777139559142]
# African-American
# uf [False, False]
# delta [0.13628458052204104, 1.3377388569779571]
# African-American
# uf [False, False]
# delta [0.9681422902610205, 0.5688694284889786]
# African-American
# uf [False, False]
# delta [1.3840711451305103, 0.1844347142444893]
# Hispanic
# uf [False, True]
# delta [1.5920355725652553, 0.007782642877755361]
# Caucasian
# uf [False, True]
# delta [0.6960177862826277, 0.10389132143887769]
# African-American
# uf [False, False]
# delta [0.24800889314131383, 0.8480543392805612]
# Caucasian
# uf [False, False]
# delta [1.024004446570657, 0.32402716964028055]
# African-American
# uf [False, False]
# delta [0.41200222328532854, 1.0620135848201402]
# African-American
# uf [False, False]
# delta [1.1060011116426642, 0.4310067924100701]
# Caucasian
# uf [False, False]
# delta [1.4530005558213321, 0.11550339620503505]
# Caucasian
# uf [False, False]
# delta [0.6265002779106661, 0.9577516981025176]
# Caucasian
# uf [False, False]
# delta [0.21325013895533304, 1.378875849051259]
# African-American
# uf [False, False]
# delta [0.006625069477666515, 1.5894379245256296]
# African-American
# uf [False, False]
# delta [0.9033125347388333, 0.6947189622628148]
# African-American
# uf [False, False]
# delta [1.3516562673694166, 0.2473594811314074]
# African-American
# uf [False, False]
# delta [1.5758281336847082, 0.023679740565703697]
# African-American
# uf [False, True]
# delta [1.687914066842354, 0.08816012971714815]
# Caucasian
# uf [False, True]
# delta [1.743957033421177, 0.14408006485857408]
# Hispanic
# uf [False, False]
# delta [0.7719785167105885, 0.827959967570713]
# Caucasian
# uf [False, False]
# delta [0.2859892583552942, 0.3139799837853565]
# Hispanic
# uf [False, False]
# delta [0.0429946291776471, 1.0569899918926784]
# African-American
# uf [True, False]
# delta [0.07850268541117646, 0.4284949959463392]
# Caucasian
# uf [False, False]
# delta [0.8607486572944117, 0.1142474979731696]
# Caucasian
# uf [False, False]
# delta [0.33037432864720584, 0.9571237489865848]
# Caucasian
# uf [False, False]
# delta [0.06518716432360291, 1.3785618744932924]
# African-American
# uf [True, False]
# delta [0.06740641783819855, 1.589280937246646]
# Caucasian
# uf [False, False]
# delta [0.8662967910809007, 0.6946404686233231]
# African-American
# uf [False, False]
# delta [0.3331483955404504, 1.2473202343116616]
# African-American
# uf [False, False]
# delta [1.0665741977702252, 0.5236601171558308]
# Caucasian
# uf [False, False]
# delta [1.4332870988851125, 0.1618300585779154]
# Caucasian
# uf [False, False]
# delta [0.6166435494425563, 0.9809150292889577]
# Caucasian
# uf [False, False]
# delta [0.20832177472127814, 1.3904575146444789]
# Caucasian
# uf [False, False]
# delta [0.004160887360639062, 1.5952287573222395]
# African-American
# uf [True, False]
# delta [0.09791955631968047, 1.6976143786611197]
# African-American
# uf [False, False]
# delta [0.8510402218401598, 0.7488071893305599]
# Caucasian
# uf [False, False]
# delta [1.3255201109200798, 0.27440359466527997]
# African-American
# uf [False, False]
# delta [0.5627600554600399, 1.03720179733264]
# Caucasian
# uf [False, False]
# delta [1.18138002773002, 0.41860089866632]
# Hispanic
# uf [False, False]
# delta [0.49069001386501, 1.10930044933316]
# African-American
# uf [False, False]
# delta [0.145345006932505, 0.45465022466658]
# Other
# uf [False, False]
# delta [0.9726725034662526, 0.12732511233329]
# Caucasian
# uf [False, True]
# delta [0.38633625173312625, 0.03633744383335501]
# Hispanic
# uf [False, False]
# delta [0.09316812586656312, 0.8818312780833225]
# African-American
# uf [True, False]
# delta [0.05341593706671845, 0.3409156390416612]
# Caucasian
# uf [False, False]
# delta [0.8732920314666408, 0.0704578195208306]
# Caucasian
# uf [False, False]
# delta [0.3366460157333204, 0.9352289097604153]
# Caucasian
# uf [False, False]
# delta [0.06832300786666021, 1.3676144548802076]
# Hispanic
# uf [True, False]
# delta [0.0658384960666699, 1.5838072274401038]
# African-American
# uf [True, False]
# delta [0.13291924803333496, 0.6919036137200519]
# African-American
# uf [False, False]
# delta [0.8335403759833325, 0.24595180686002596]
# African-American
# uf [False, False]
# delta [1.3167701879916662, 0.022975903430012976]
# African-American
# uf [False, True]
# delta [1.5583850939958332, 0.08851204828499351]
# Caucasian
# uf [False, True]
# delta [1.6791925469979168, 0.14425602414249677]
# Caucasian
# uf [False, False]
# delta [0.7395962734989584, 0.8278719879287516]
# African-American
# uf [False, False]
# delta [0.26979813674947917, 1.3139359939643758]
# Hispanic
# uf [False, False]
# delta [1.0348990683747397, 0.5569679969821879]
# African-American
# uf [False, False]
# delta [0.41744953418736985, 0.17848399849109395]
# Caucasian
# uf [False, True]
# delta [1.108724767093685, 0.010758000754453032]
# Caucasian
# uf [False, False]
# delta [0.45436238354684255, 0.8946209996227735]
# Caucasian
# uf [False, False]
# delta [0.12718119177342127, 1.3473104998113867]
# African-American
# uf [True, False]
# delta [0.03640940411328937, 1.5736552499056935]
# African-American
# uf [False, False]
# delta [0.8817952979433553, 0.6868276249528468]
# African-American
# uf [False, False]
# delta [1.3408976489716777, 0.24341381247642338]
# African-American
# uf [False, False]
# delta [1.570448824485839, 0.021706906238211685]
# Hispanic
# uf [False, True]
# delta [1.6852244122429196, 0.08914654688089416]
# Caucasian
# uf [False, True]
# delta [0.7426122061214598, 0.14457327344044707]
# African-American
# uf [False, False]
# delta [0.2713061030607299, 0.8277133632797765]
# African-American
# uf [False, False]
# delta [1.035653051530365, 0.3138566816398882]
# Caucasian
# uf [False, False]
# delta [1.4178265257651825, 0.05692834081994411]
# Hispanic
# uf [False, False]
# delta [0.6089132628825913, 0.9284641704099721]
# Caucasian
# uf [False, False]
# delta [0.20445663144129564, 0.36423208520498607]
# African-American
# uf [False, False]
# delta [0.002228315720647814, 1.0821160426024932]
# African-American
# uf [False, False]
# delta [0.9011141578603239, 0.4410580213012466]
