# %%
import argparse
import colorsys
import csv

import pandas as pd
import matplotlib.pyplot as plt
from numpy import dtype
import math
import sys
sys.path.append("../../../../../../../")
from algorithm.per_item import Accuracy_workload as workload
import seaborn as sns
import matplotlib.dates as mdates
import numpy as np

# %%
import os
os.getcwd()
# Out:
# '/Users/jinyangli/OngoingProjects/dynamic_fairness/DFMonitor/experiments/stocks/stock_nanosecond/dynamic_method_fixed_window/compare_acc_change_window_size/alpha_99995'

# %%
def get_integer(alpha):
    while not math.isclose(alpha, round(alpha), rel_tol=1e-9):  # Use a small tolerance
        alpha *= 10
    return int(alpha)



time_period = "14-00--14-10"
date = "20241015"
len_chunk = 1
# Prepare the result file for writing

alpha = 0.99995


threshold = 0.4
label_prediction = "predicted_direction"
label_ground_truth = "next_price_direction"
correctness_column = "prediction_binary_correctness"
use_two_counters = True
time_unit = "10000 nanosecond"
# window_size_units = "10"
checking_interval = "100000 nanosecond"
use_nanosecond = True
window_size_unit = 500


time_start = pd.Timestamp('2024-10-15 14:00:10.50', tz='UTC')
time_end = pd.Timestamp('2024-10-15 14:00:11.50', tz='UTC')


fixed_window_file_name = f"check_interval_100000/stocks_compare_Accuracy_sector_20241015_14-00--14-10_alpha_{str(get_integer(alpha))}_time_unit_{time_unit}*{window_size_unit}_check_interval_{checking_interval}_start_time_" \
            f"{time_start}_end_time_{time_end}.csv"



Tin = 400
Tb = 600
adaptive_file_name = f"../../../dynamic_method_adaptive_window/compare_acc_change_Tb/alpha_99995/stocks_compare_Accuracy_sector_{date}_{time_period}_alpha_{str(get_integer(alpha))}" + \
            f"_time_unit_{time_unit}_check_interval_{checking_interval}_Tin_{Tin}_Tb_{Tb}" + \
             f"_start_time_{time_start}_end_time_{time_end}.csv"

# %%
fixed_window_result = pd.read_csv(fixed_window_file_name)

print(len(fixed_window_result))

fixed_window_result["check_points"] = pd.to_datetime(fixed_window_result["check_points"])

print(len(fixed_window_result))

print("number of reset times: ", len(fixed_window_result[fixed_window_result["window_reset"] == "reset"]))
# Out:
# 9958
# 9958
# number of reset times:  199

# %%
adaptive_window_result = pd.read_csv(adaptive_file_name)

print(len(adaptive_window_result))

adaptive_window_result["check_points"] = pd.to_datetime(adaptive_window_result["check_points"])

print(len(adaptive_window_result))

print("number of reset times: ", len(adaptive_window_result[adaptive_window_result["window_reset"] == "reset"]))
# Out:
# 10102
# 10102
# number of reset times:  144

# %%
# compare checkpoints where column window_reset has value "reset"

fixed_window_reset = fixed_window_result[fixed_window_result["window_reset"] == "reset"]
print(len(fixed_window_reset))
dynamic_window_reset = adaptive_window_result[adaptive_window_result["window_reset"] == "reset"]
print(len(dynamic_window_reset))
# Out:
# 199
# 144

# %% [markdown]
# # compare the fixed_window_reset and dynamic window reset

# %%
# Merge the two reset DataFrames on `check_points` to compare where resets align or differ
comparison_df = pd.merge(
    fixed_window_reset[['check_points', 'window_reset']],
    dynamic_window_reset[['check_points', 'window_reset']],
    on="check_points",
    how="outer",
    suffixes=('_fixed', '_dynamic')
)

# Add a column to show if the reset status matches between the two
comparison_df['reset_match'] = comparison_df['window_reset_fixed'] == comparison_df['window_reset_dynamic']

# Check results
print(comparison_df)

# Separate out mismatches for further analysis if needed
mismatches = comparison_df[comparison_df['reset_match'] == False]
print("Mismatches:")
print(mismatches)
mismatch_file_name = f"mismatch_time_unit_{time_unit}_checking_interval_{checking_interval}_window_size_unit_{window_size_unit}_Tin_{Tin}_Tb_{Tb}.csv"
mismatches.to_csv(mismatch_file_name, index=False)
# Out:
#                            check_points window_reset_fixed  \
# 0   2024-10-15 14:00:10.507027418+00:00              reset
# 1   2024-10-15 14:00:10.512027418+00:00              reset
# 2   2024-10-15 14:00:10.515675487+00:00                NaN
# 3   2024-10-15 14:00:10.517027418+00:00              reset
# 4   2024-10-15 14:00:10.522027418+00:00              reset
# ..                                  ...                ...
# 338 2024-10-15 14:00:11.486464200+00:00                NaN
# 339 2024-10-15 14:00:11.487027418+00:00              reset
# 340 2024-10-15 14:00:11.492027418+00:00              reset
# 341 2024-10-15 14:00:11.492135524+00:00                NaN
# 342 2024-10-15 14:00:11.497027418+00:00              reset
#
#     window_reset_dynamic  reset_match
# 0                    NaN        False
# 1                    NaN        False
# 2                  reset        False
# 3                    NaN        False
# 4                    NaN        False
# ..                   ...          ...
# 338                reset        False
# 339                  NaN        False
# 340                  NaN        False
# 341                reset        False
# 342                  NaN        False
#
# [343 rows x 4 columns]
# Mismatches:
#                            check_points window_reset_fixed  \
# 0   2024-10-15 14:00:10.507027418+00:00              reset
# 1   2024-10-15 14:00:10.512027418+00:00              reset
# 2   2024-10-15 14:00:10.515675487+00:00                NaN
# 3   2024-10-15 14:00:10.517027418+00:00              reset
# 4   2024-10-15 14:00:10.522027418+00:00              reset
# ..                                  ...                ...
# 338 2024-10-15 14:00:11.486464200+00:00                NaN
# 339 2024-10-15 14:00:11.487027418+00:00              reset
# 340 2024-10-15 14:00:11.492027418+00:00              reset
# 341 2024-10-15 14:00:11.492135524+00:00                NaN
# 342 2024-10-15 14:00:11.497027418+00:00              reset
#
#     window_reset_dynamic  reset_match
# 0                    NaN        False
# 1                    NaN        False
# 2                  reset        False
# 3                    NaN        False
# 4                    NaN        False
# ..                   ...          ...
# 338                reset        False
# 339                  NaN        False
# 340                  NaN        False
# 341                reset        False
# 342                  NaN        False
#
# [343 rows x 4 columns]

# %%
mismatch = pd.read_csv(mismatch_file_name)
print(mismatch)
# Out:
#                             check_points window_reset_fixed  \
# 0    2024-10-15 14:00:10.507027418+00:00              reset
# 1    2024-10-15 14:00:10.512027418+00:00              reset
# 2    2024-10-15 14:00:10.515675487+00:00                NaN
# 3    2024-10-15 14:00:10.517027418+00:00              reset
# 4    2024-10-15 14:00:10.522027418+00:00              reset
# ..                                   ...                ...
# 338  2024-10-15 14:00:11.486464200+00:00                NaN
# 339  2024-10-15 14:00:11.487027418+00:00              reset
# 340  2024-10-15 14:00:11.492027418+00:00              reset
# 341  2024-10-15 14:00:11.492135524+00:00                NaN
# 342  2024-10-15 14:00:11.497027418+00:00              reset
#
#     window_reset_dynamic  reset_match
# 0                    NaN        False
# 1                    NaN        False
# 2                  reset        False
# 3                    NaN        False
# 4                    NaN        False
# ..                   ...          ...
# 338                reset        False
# 339                  NaN        False
# 340                  NaN        False
# 341                reset        False
# 342                  NaN        False
#
# [343 rows x 4 columns]

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Calculate batch lengths for fixed_window_reset
fixed_window_reset['batch_length'] = fixed_window_reset['check_points'].diff().dt.total_seconds()
# Drop the first NaN value resulting from the diff operation
fixed_window_reset = fixed_window_reset.dropna(subset=['batch_length'])



# Calculate batch lengths for dynamic_window_reset
dynamic_window_reset['batch_length'] = dynamic_window_reset['check_points'].diff().dt.total_seconds()
dynamic_window_reset = dynamic_window_reset.dropna(subset=['batch_length'])

# Plot distributions
plt.figure(figsize=(12, 6))

plt.subplot(1, 2, 1)
plt.hist(fixed_window_reset['batch_length'], bins=20, edgecolor='black')
plt.title("Fixed Window Batch Length Distribution")
plt.xlabel("Batch Length (seconds)")
plt.ylabel("Frequency")

plt.subplot(1, 2, 2)
plt.hist(dynamic_window_reset['batch_length'], bins=20, edgecolor='black')
plt.title("Dynamic Window Batch Length Distribution")
plt.xlabel("Batch Length (seconds)")
plt.ylabel("Frequency")

plt.tight_layout()
plt.show()

# Print basic statistics for analysis
print("Fixed Window Batch Length Statistics:")
print(fixed_window_reset['batch_length'].describe())

print("\nDynamic Window Batch Length Statistics:")
print(dynamic_window_reset['batch_length'].describe())
# Out:
# /var/folders/sy/m1107g5j24x3w6mcyb9njvyw0000gn/T/ipykernel_96926/2058661376.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   fixed_window_reset['batch_length'] = fixed_window_reset['check_points'].diff().dt.total_seconds()
# /var/folders/sy/m1107g5j24x3w6mcyb9njvyw0000gn/T/ipykernel_96926/2058661376.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dynamic_window_reset['batch_length'] = dynamic_window_reset['check_points'].diff().dt.total_seconds()
# Fixed Window Batch Length Statistics:
# count    1.980000e+02
# mean     5.000000e-03
# std      8.695604e-19
# min      5.000000e-03
# 25%      5.000000e-03
# 50%      5.000000e-03
# 75%      5.000000e-03
# max      5.000000e-03
# Name: batch_length, dtype: float64
#
# Dynamic Window Batch Length Statistics:
# count    143.000000
# mean       0.006828
# std        0.001273
# min        0.004051
# 25%        0.006105
# 50%        0.006452
# 75%        0.007102
# max        0.012622
# Name: batch_length, dtype: float64

# %% [markdown]
#  # compare fixed window results with different window sizes

# %%
def get_integer(alpha):
    while not math.isclose(alpha, round(alpha), rel_tol=1e-9):  # Use a small tolerance
        alpha *= 10
    return int(alpha)



time_period = "14-00--14-10"
date = "20241015"
len_chunk = 1
# Prepare the result file for writing

alpha = 0.99995


threshold = 0.4
label_prediction = "predicted_direction"
label_ground_truth = "next_price_direction"
correctness_column = "prediction_binary_correctness"
use_two_counters = True
time_unit = "10000 nanosecond"
# window_size_units = "10"
checking_interval = "100000 nanosecond"
use_nanosecond = True
window_size_unit1 = 200
window_size_unit2 = 800

time_start = pd.Timestamp('2024-10-15 14:00:8.00', tz='UTC')
time_end = pd.Timestamp('2024-10-15 14:00:11.00', tz='UTC')


fixed_window_file_name1 = f"check_interval_100000/stocks_compare_Accuracy_sector_20241015_14-00--14-10_alpha_{str(get_integer(alpha))}_time_unit_{time_unit}*{window_size_unit}_check_interval_{checking_interval}_start_time_" \
            f"{time_start}_end_time_{time_end}.csv"



fixed_window_file_name2 = f"check_interval_100000/stocks_compare_Accuracy_sector_20241015_14-00--14-10_alpha_{str(get_integer(alpha))}_time_unit_{time_unit}*{window_size_unit2}_check_interval_{checking_interval}_start_time_" \
            f"{time_start}_end_time_{time_end}.csv"

accuracy_fixed_window1 = pd.read_csv(fixed_window_file_name1)
accuracy_fixed_window2 = pd.read_csv(fixed_window_file_name2)

print(len(accuracy_fixed_window1))
print(len(accuracy_fixed_window2))
# Out:
# 29994
# 29994

# %%
num_resets1 = len(accuracy_fixed_window1[accuracy_fixed_window1["window_reset"] == "reset"])
num_resets2 = len(accuracy_fixed_window2[accuracy_fixed_window2["window_reset"] == "reset"])
print("number of resets in fixed window with window size 200: ", num_resets1)
print("number of resets in fixed window with window size 800: ", num_resets2)
# Out:
# number of resets in fixed window with window size 200:  599
# number of resets in fixed window with window size 800:  374

# %%
# Merge the two reset DataFrames on `check_points` to compare where resets align or differ
comparison_df = pd.merge(
    accuracy_fixed_window1,
    accuracy_fixed_window2,
    on="check_points",
    how="outer",
    suffixes=('_200', '_800')
)

print(comparison_df.describe())


# print the accuracy hange of all accuracy columns between two fixed window results
for index, row in comparison_df.iterrows():
    if row["window_reset_200"] == "reset":
# Out:
#        Technology_time_decay_200  CommunicationServices_time_decay_200  \
# count               29994.000000                          29994.000000
# mean                    0.642341                              0.593376
# std                     0.021164                              0.049904
# min                     0.000000                              0.000000
# 25%                     0.629990                              0.576289
# 50%                     0.642061                              0.594056
# 75%                     0.655514                              0.618640
# max                     0.809524                              1.000000
#
#        Energy_time_decay_200  ConsumerDefensive_time_decay_200  \
# count           29994.000000                      29994.000000
# mean                0.576838                          0.625609
# std                 0.097770                          0.051985
# min                 0.000000                          0.506868
# 25%                 0.557438                          0.602848
# 50%                 0.586618                          0.630941
# 75%                 0.616074                          0.657047
# max                 0.755995                          1.000000
#
#        ConsumerCyclical_time_decay_200  FinancialServices_time_decay_200  \
# count                     29994.000000                      29994.000000
# mean                          0.620802                          0.558046
# std                           0.045284                          0.064414
# min                           0.000000                          0.000000
# 25%                           0.602941                          0.513413
# 50%                           0.631025                          0.577153
# 75%                           0.638815                          0.596218
# max                           0.708534                          0.747766
#
#        Healthcare_time_decay_200  Industrials_200  \
# count               29994.000000     29994.000000
# mean                    0.601244         0.688070
# std                     0.094687         0.235029
# min                     0.000000         0.000000
# 25%                     0.582064         0.482822
# 50%                     0.629905         0.631523
# 75%                     0.640582         1.000000
# max                     1.000000         1.000000
#
#        BasicMaterials_time_decay_200  Technology_time_decay_800  \
# count                   29994.000000               29994.000000
# mean                        0.374982                   0.642347
# std                         0.378971                   0.021206
# min                         0.000000                   0.000000
# 25%                         0.000000                   0.629413
# 50%                         0.508722                   0.641786
# 75%                         0.846245                   0.655617
# max                         1.000000                   0.809524
#
#        CommunicationServices_time_decay_800  Energy_time_decay_800  \
# count                          29994.000000           29994.000000
# mean                               0.593386               0.576668
# std                                0.049944               0.097843
# min                                0.000000               0.000000
# 25%                                0.576457               0.557239
# 50%                                0.593762               0.586386
# 75%                                0.618642               0.616155
# max                                1.000000               0.757328
#
#        ConsumerDefensive_time_decay_800  ConsumerCyclical_time_decay_800  \
# count                      29994.000000                     29994.000000
# mean                           0.625622                         0.620948
# std                            0.051914                         0.045257
# min                            0.507205                         0.000000
# 25%                            0.603577                         0.602888
# 50%                            0.630927                         0.630765
# 75%                            0.656409                         0.638725
# max                            1.000000                         0.707631
#
#        FinancialServices_time_decay_800  Healthcare_time_decay_800  \
# count                      29994.000000               29994.000000
# mean                           0.557548                   0.600916
# std                            0.064543                   0.094849
# min                            0.000000                   0.000000
# 25%                            0.510688                   0.581777
# 50%                            0.577069                   0.629589
# 75%                            0.596054                   0.640300
# max                            0.746673                   1.000000
#
#        Industrials_800  BasicMaterials_time_decay_800
# count     29994.000000                   29994.000000
# mean          0.688509                       0.375986
# std           0.234769                       0.380158
# min           0.000000                       0.000000
# 25%           0.482631                       0.000000
# 50%           0.631726                       0.508449
# 75%           1.000000                       0.849880
# max           1.000000                       1.000000
# 2024-10-15 14:00:08.005207529+00:00
# Technology_time_decay 0.7391304347826088 0.7391304347826088
# CommunicationServices_time_decay 0.0 0.0
# Energy_time_decay 0.0 0.0
# ConsumerDefensive_time_decay 1.0 1.0
# ConsumerCyclical_time_decay 0.0 0.0
# FinancialServices_time_decay 0.4444444444444444 0.4444444444444444
# Healthcare_time_decay 0.0 0.0
# Industrials 0.0 0.0
# BasicMaterials_time_decay 0.0 0.0
#
#
# 2024-10-15 14:00:08.008207529+00:00
# Technology_time_decay 0.7391304347826088 0.7391304347826088
# CommunicationServices_time_decay 0.0 0.0
# Energy_time_decay 0.0 0.0
# ConsumerDefensive_time_decay 1.0 1.0
# ConsumerCyclical_time_decay 0.0 0.0
# FinancialServices_time_decay 0.3989899266229402 0.3983741627354374
# Healthcare_time_decay 0.0 0.0
# Industrials 0.0 0.0
# BasicMaterials_time_decay 0.0 0.0
#
#
# 2024-10-15 14:00:08.010207529+00:00
# Technology_time_decay 0.7113292230458105 0.7110045508380309
# CommunicationServices_time_decay 1.0 1.0
# Energy_time_decay 0.0 0.0
# ConsumerDefensive_time_decay 0.6666840286458449 0.6655738869350825
# ConsumerCyclical_time_decay 0.0 0.0
# FinancialServices_time_decay 0.3989899266229402 0.3983741627354374
# Healthcare_time_decay 0.0 0.0
# Industrials 1.0 1.0
# BasicMaterials_time_decay 0.0 0.0
#
#
# 2024-10-15 14:00:08.015207529+00:00
# Technology_time_decay 0.7186617267685796 0.7181589548848757
# CommunicationServices_time_decay 1.0 1.0
# Energy_time_decay 0.0 0.0
# ConsumerDefensive_time_decay 0.7435121366265218 0.7425687350965157
# ConsumerCyclical_time_decay 0.6774423546775128 0.6772516490503493
# FinancialServices_time_decay 0.3989899266229403 0.3983741627354374
# Healthcare_time_decay 1.0 1.0
# Industrials 1.0 1.0
# BasicMaterials_time_decay 0.0 0.0
#
#
# 2024-10-15 14:00:08.016207529+00:00
# Technology_time_decay 0.6977027309757378 0.6987592420786181
# CommunicationServices_time_decay 1.0 1.0
# Energy_time_decay 0.0 0.0
# ConsumerDefensive_time_decay 0.7435121366265218 0.7425687350965157
# ConsumerCyclical_time_decay 0.6774423546775128 0.6772516490503492
# FinancialServices_time_decay 0.3989899266229403 0.3983741627354374
# Healthcare_time_decay 1.0 1.0
# Industrials 1.0 1.0
# BasicMaterials_time_decay 0.0 0.0
#
#
# 2024-10-15 14:00:08.020207529+00:00
# Technology_time_decay 0.6950853817124655 0.6959201867535026
# CommunicationServices_time_decay 0.6611580263442496 0.662252130701486
# Energy_time_decay 0.0 0.0
# ConsumerDefensive_time_decay 0.7435121366265218 0.7425687350965157
# ConsumerCyclical_time_decay 0.6774423546775127 0.6772516490503492
# FinancialServices_time_decay 0.3989899266229403 0.3983741627354374
# Healthcare_time_decay 0.4937501692696946 0.4900010832116812
# Industrials 1.0 1.0
# BasicMaterials_time_decay 0.0 0.0
#
#
# 2024-10-15 14:00:08.024207529+00:00
# Technology_time_decay 0.695551111788642 0.6963001802485532
# CommunicationServices_time_decay 0.6611580263442496 0.662252130701486
# Energy_time_decay 0.0 0.0
# ConsumerDefensive_time_decay 0.7435121366265218 0.7425687350965156
# ConsumerCyclical_time_decay 0.6774423546775127 0.6772516490503492
# FinancialServices_time_decay 0.4586656954743242 0.4569617995887483
# Healthcare_time_decay 0.3250353781961534 0.324504261402972
# Industrials 1.0 1.0
# BasicMaterials_time_decay 0.0 0.0
#
#
# 2024-10-15 14:00:08.025207529+00:00
# Technology_time_decay 0.695551111788642 0.6963001802485532
# CommunicationServices_time_decay 0.6611580263442496 0.662252130701486
# Energy_time_decay 0.0 0.0
# ConsumerDefensive_time_decay 0.7216516746433931 0.7202511515287487
# ConsumerCyclical_time_decay 0.6774423546775127 0.6772516490503492
# FinancialServices_time_decay 0.4586656954743243 0.4569617995887483
# Healthcare_time_decay 0.3250353781961534 0.324504261402972
# Industrials 1.0 1.0
# BasicMaterials_time_decay 0.0 0.0
#
#
# 2024-10-15 14:00:08.030207529+00:00
# Technology_time_decay 0.6611119507599122 0.6617942424059902
# CommunicationServices_time_decay 0.6611580263442496 0.662252130701486
# Energy_time_decay 0.0 0.0
# ConsumerDefensive_time_decay 0.7216516746433931 0.7202511515287487
# ConsumerCyclical_time_decay 0.6774423546775127 0.6772516490503492
# FinancialServices_time_decay 0.4586656954743243 0.4569617995887483
# Healthcare_time_decay 0.2407043387996684 0.2401010615486209
# Industrials 1.0 1.0
# BasicMaterials_time_decay 0.0 0.0
#
#
# 2024-10-15 14:00:08.032207529+00:00
# Technology_time_decay 0.6559905871597387 0.6567834024377766
# CommunicationServices_time_decay 0.6611580263442496 0.6622521307014859
# Energy_time_decay 0.0 0.0
# ConsumerDefensive_time_decay 0.7216516746433931 0.7202511515287489
# ConsumerCyclical_time_decay 0.6407809619580714 0.64121545750393
# FinancialServices_time_decay 0.4586656954743243 0.4569617995887483
# Healthcare_time_decay 0.2407043387996684 0.2401010615486209
# Industrials 1.0 1.0
# BasicMaterials_time_decay 0.0 0.0
#
#
# 2024-10-15 14:00:08.035207529+00:00
# Technology_time_decay 0.6508185954956097 0.6515329578216005
# CommunicationServices_time_decay 0.6611580263442496 0.6622521307014859
# Energy_time_decay 0.0 0.0
# ConsumerDefensive_time_decay 0.6850496472382065 0.6841147549830031
# ConsumerCyclical_time_decay 0.6407809619580714 0.64121545750393
# FinancialServices_time_decay 0.4586656954743242 0.4569617995887483
# Healthcare_time_decay 0.2407043387996683 0.2401010615486209
# Industrials 1.0 1.0
# BasicMaterials_time_decay 0.0 0.0
#
#
# 2024-10-15 14:00:08.045207529+00:00
# Technology_time_decay 0.6433013965116816 0.6440804527755901
# CommunicationServices_time_decay 0.6505221418157842 0.6502095897143878
# Energy_time_decay 0.0 0.0
# ConsumerDefensive_time_decay 0.7077265948688448 0.7065823716053901
# ConsumerCyclical_time_decay 0.5943200582212872 0.5947217777244505
# FinancialServices_time_decay 0.4586656954743242 0.4569617995887483
# Healthcare_time_decay 0.1313835396330767 0.130899574632038
# Industrials 1.0 1.0
# BasicMaterials_time_decay 0.0 0.0
#
#
# 2024-10-15 14:00:08.048207529+00:00
# Technology_time_decay 0.6433013965116816 0.6440804527755902
# CommunicationServices_time_decay 0.63797766829215 0.6379713360362708
# Energy_time_decay 0.6737912487964416 0.6724109614346676
# ConsumerDefensive_time_decay 0.7077265948688448 0.7065823716053901
# ConsumerCyclical_time_decay 0.5595709515412226 0.5601331847902118
# FinancialServices_time_decay 0.5134132492383354 0.5106875409156854
# Healthcare_time_decay 0.1313835396330767 0.130899574632038
# Industrials 1.0 1.0
# BasicMaterials_time_decay 0.0 0.0
#
#
# 2024-10-15 14:00:08.050207529+00:00
# Technology_time_decay 0.6433013965116816 0.6440804527755902
# CommunicationServices_time_decay 0.6379776682921501 0.6379713360362708
# Energy_time_decay 0.572540525098555 0.5716056639348761
# ConsumerDefensive_time_decay 0.6659374754853504 0.6642355158596851
# ConsumerCyclical_time_decay 0.591651723078574 0.5928995521591195
# FinancialServices_time_decay 0.5134132492383355 0.5106875409156854
# Healthcare_time_decay 0.1313835396330767 0.130899574632038
# Industrials 1.0 1.0
# BasicMaterials_time_decay 0.0 0.0
#
#
# 2024-10-15 14:00:08.055207529+00:00
# Technology_time_decay 0.6606241265500274 0.6612687292297585
# CommunicationServices_time_decay 0.6379776682921501 0.6379713360362708
# Energy_time_decay 0.581535948770779 0.5802473113334131
# ConsumerDefensive_time_decay 0.6659374754853503 0.6642355158596852
# ConsumerCyclical_time_decay 0.5916517230785739 0.5928995521591195
# FinancialServices_time_decay 0.5134132492383355 0.5106875409156854
# Healthcare_time_decay 0.1313835396330767 0.130899574632038
# Industrials 1.0 1.0
# BasicMaterials_time_decay 0.0 0.0
#
#
# 2024-10-15 14:00:08.056207529+00:00
# Technology_time_decay 0.6606241265500274 0.6612687292297585
# CommunicationServices_time_decay 0.6379776682921501 0.6379713360362708
# Energy_time_decay 0.581535948770779 0.5802473113334131
# ConsumerDefensive_time_decay 0.6659374754853503 0.6642355158596852
# ConsumerCyclical_time_decay 0.5916517230785739 0.5928995521591195
# FinancialServices_time_decay 0.5134132492383355 0.5106875409156854
# Healthcare_time_decay 0.1313835396330767 0.130899574632038
# Industrials 1.0 1.0
# BasicMaterials_time_decay 0.0 0.0
#
#
# 2024-10-15 14:00:08.060207529+00:00
# Technology_time_decay 0.657936362919189 0.6586112767345709
# CommunicationServices_time_decay 0.6379776682921501 0.6379713360362708
# Energy_time_decay 0.5782428749213228 0.5770134484530944
# ConsumerDefensive_time_decay 0.6659374754853504 0.6642355158596852
# ConsumerCyclical_time_decay 0.5916517230785739 0.5928995521591195
# FinancialServices_time_decay 0.5134132492383354 0.5106875409156854
# Healthcare_time_decay 0.1313835396330767 0.130899574632038
# Industrials 1.0 1.0
# BasicMaterials_time_decay 0.0 0.0
#
#
# 2024-10-15 14:00:08.064207529+00:00
# Technology_time_decay 0.6531502221398988 0.654077201140966
# CommunicationServices_time_decay 0.6105543935057645 0.6110074354036599
# Energy_time_decay 0.5444255146729747 0.5441223101946282
# ConsumerDefensive_time_decay 0.6659374754853504 0.6642355158596852
# ConsumerCyclical_time_decay 0.5916517230785739 0.5928995521591195
# FinancialServices_time_decay 0.5134132492383354 0.5106875409156852
# Healthcare_time_decay 0.1313835396330767 0.1308995746320381
# Industrials 1.0 1.0
# BasicMaterials_time_decay 0.0 0.0
#
#
# 2024-10-15 14:00:08.065207529+00:00
# Technology_time_decay 0.6531502221398988 0.654077201140966
# CommunicationServices_time_decay 0.6105543935057645 0.6110074354036599
# Energy_time_decay 0.5444255146729747 0.5441223101946282
# ConsumerDefensive_time_decay 0.6659374754853504 0.6642355158596852
# ConsumerCyclical_time_decay 0.5916517230785739 0.5928995521591195
# FinancialServices_time_decay 0.5134132492383354 0.5106875409156852
# Healthcare_time_decay 0.1313835396330767 0.1308995746320381
# Industrials 1.0 1.0
# BasicMaterials_time_decay 0.0 0.0
#
#
# 2024-10-15 14:00:08.070207529+00:00
# Technology_time_decay 0.6478997584970784 0.6488200103907327
# CommunicationServices_time_decay 0.6105543935057646 0.6110074354036599
# Energy_time_decay 0.5444255146729747 0.5441223101946282
# ConsumerDefensive_time_decay 0.6659374754853504 0.6642355158596852
# ConsumerCyclical_time_decay 0.5752520049509723 0.5763852372543589
# FinancialServices_time_decay 0.5134132492383353 0.5106875409156852
# Healthcare_time_decay 0.1313835396330767 0.1308995746320381
# Industrials 1.0 1.0
# BasicMaterials_time_decay 0.0 0.0
#
#
# 2024-10-15 14:00:08.072207529+00:00
# Technology_time_decay 0.6507781089474194 0.6517334678341721
# CommunicationServices_time_decay 0.6105543935057646 0.6110074354036599
# Energy_time_decay 0.5444255146729747 0.5441223101946282
# ConsumerDefensive_time_decay 0.6659374754853504 0.6642355158596852
# ConsumerCyclical_time_decay 0.581203160250224 0.5822037763128416
# FinancialServices_time_decay 0.5134132492383353 0.5106875409156852
# Healthcare_time_decay 0.1313835396330767 0.130899574632038
# Industrials 1.0 1.0
# BasicMaterials_time_decay 0.0 0.0
#
#
# 2024-10-15 14:00:08.075207529+00:00
# Technology_time_decay 0.6563959012452502 0.6574177260805013
# CommunicationServices_time_decay 0.6105543935057646 0.6110074354036599
# Energy_time_decay 0.5444255146729747 0.5441223101946282
# ConsumerDefensive_time_decay 0.6659374754853505 0.6642355158596852
# ConsumerCyclical_time_decay 0.581203160250224 0.5822037763128416
# FinancialServices_time_decay 0.5134132492383353 0.5106875409156852
# Healthcare_time_decay 0.1313835396330767 0.130899574632038
# Industrials 1.0 1.0
# BasicMaterials_time_decay 0.0 0.0
#
#
# 2024-10-15 14:00:08.085207529+00:00
# Technology_time_decay 0.6513403408572221 0.6523432836343939
# CommunicationServices_time_decay 0.5828650665515482 0.5832149833390201
# Energy_time_decay 0.5444255146729746 0.5441223101946282
# ConsumerDefensive_time_decay 0.6659374754853505 0.6642355158596852
# ConsumerCyclical_time_decay 0.6352768711168382 0.6363279234966449
# FinancialServices_time_decay 0.5645763634056455 0.5615881704582143
# Healthcare_time_decay 0.1313835396330767 0.130899574632038
# Industrials 1.0 1.0
# BasicMaterials_time_decay 0.0 0.0
#
#
# 2024-10-15 14:00:08.088207529+00:00
# Technology_time_decay 0.6513403408572221 0.6523432836343939
# CommunicationServices_time_decay 0.5828650665515482 0.5832149833390201
# Energy_time_decay 0.5444255146729746 0.5441223101946282
# ConsumerDefensive_time_decay 0.6659374754853505 0.6642355158596852
# ConsumerCyclical_time_decay 0.6352768711168382 0.6363279234966449
# FinancialServices_time_decay 0.5645763634056455 0.5615881704582143
# Healthcare_time_decay 0.1313835396330767 0.130899574632038
# Industrials 1.0 1.0
# BasicMaterials_time_decay 0.0 0.0
#
#
# 2024-10-15 14:00:08.090207529+00:00
# Technology_time_decay 0.6513403408572221 0.6523432836343939
# CommunicationServices_time_decay 0.5828650665515482 0.5832149833390201
# Energy_time_decay 0.5444255146729746 0.5441223101946282
# ConsumerDefensive_time_decay 0.6659374754853505 0.6642355158596852
# ConsumerCyclical_time_decay 0.6352768711168382 0.6363279234966449
# FinancialServices_time_decay 0.5645763634056455 0.5615881704582143
# Healthcare_time_decay 0.1313835396330767 0.130899574632038
# Industrials 1.0 1.0
# BasicMaterials_time_decay 0.0 0.0
#
#
# 2024-10-15 14:00:08.095207529+00:00
# Technology_time_decay 0.6487807483388688 0.6497803868761335
# CommunicationServices_time_decay 0.5828650665515481 0.5832149833390201
# Energy_time_decay 0.5444255146729747 0.5441223101946282
# ConsumerDefensive_time_decay 0.6659374754853504 0.6642355158596851
# ConsumerCyclical_time_decay 0.6352768711168382 0.6363279234966449
# FinancialServices_time_decay 0.5645763634056455 0.5615881704582144
# Healthcare_time_decay 0.1313835396330767 0.1308995746320381
# Industrials 1.0 1.0
# BasicMaterials_time_decay 0.0 0.0
#
#
# 2024-10-15 14:00:08.096207529+00:00
# Technology_time_decay 0.6487807483388688 0.6497803868761335
# CommunicationServices_time_decay 0.5828650665515481 0.5832149833390201
# Energy_time_decay 0.5444255146729747 0.5441223101946282
# ConsumerDefensive_time_decay 0.6659374754853504 0.6642355158596851
# ConsumerCyclical_time_decay 0.6352768711168382 0.6363279234966449
# FinancialServices_time_decay 0.5645763634056455 0.5615881704582144
# Healthcare_time_decay 0.1313835396330767 0.1308995746320381
# Industrials 1.0 1.0
# BasicMaterials_time_decay 0.0 0.0
#
#
# 2024-10-15 14:00:08.100207529+00:00
# Technology_time_decay 0.6517998153946807 0.6528199056785422
# CommunicationServices_time_decay 0.5828650665515482 0.5832149833390201
# Energy_time_decay 0.5444255146729746 0.5441223101946282
# ConsumerDefensive_time_decay 0.6659374754853504 0.6642355158596851
# ConsumerCyclical_time_decay 0.6704664378574919 0.6716851225032409
# FinancialServices_time_decay 0.5380480053733722 0.5361490648693475
# Healthcare_time_decay 0.1313835396330767 0.1308995746320381
# Industrials 1.0 1.0
# BasicMaterials_time_decay 0.0 0.0
#
#
# 2024-10-15 14:00:08.104207529+00:00
# Technology_time_decay 0.6435962396845496 0.6447126224052884
# CommunicationServices_time_decay 0.5853356889031726 0.5855034071127518
# Energy_time_decay 0.5550207113881891 0.5544622331987549
# ConsumerDefensive_time_decay 0.6659374754853504 0.6642355158596851
# ConsumerCyclical_time_decay 0.6704664378574919 0.6716851225032408
# FinancialServices_time_decay 0.5380480053733722 0.5361490648693475
# Healthcare_time_decay 0.1089368126135019 0.1087882578479713
# Industrials 1.0 1.0
# BasicMaterials_time_decay 0.0 0.0
#
#
# 2024-10-15 14:00:08.105207529+00:00
# Technology_time_decay 0.6532917442547379 0.6544819482028588
# CommunicationServices_time_decay 0.5853356889031727 0.5855034071127518
# Energy_time_decay 0.555020711388189 0.5544622331987549
# ConsumerDefensive_time_decay 0.6659374754853504 0.6642355158596851
# ConsumerCyclical_time_decay 0.6704664378574918 0.6716851225032408
# FinancialServices_time_decay 0.538048005373372 0.5361490648693475
# Healthcare_time_decay 0.1089368126135019 0.1087882578479713
# Industrials 1.0 1.0
# BasicMaterials_time_decay 0.0 0.0
#
#
# 2024-10-15 14:00:08.110207529+00:00
# Technology_time_decay 0.6532917442547379 0.6544819482028588
# CommunicationServices_time_decay 0.5853356889031726 0.5855034071127518
# Energy_time_decay 0.5875078377087555 0.5868318486317536
# ConsumerDefensive_time_decay 0.672464094027566 0.6707625090342776
# ConsumerCyclical_time_decay 0.6704664378574918 0.6716851225032408
# FinancialServices_time_decay 0.5015140334395481 0.5002380236370982
# Healthcare_time_decay 0.5809653914079462 0.581134948555786
# Industrials 1.0 1.0
# BasicMaterials_time_decay 0.0 0.0
#
#
# 2024-10-15 14:00:08.112207529+00:00
# Technology_time_decay 0.6532917442547379 0.6544819482028588
# CommunicationServices_time_decay 0.6076597344330184 0.6074159025932784
# Energy_time_decay 0.5875078377087555 0.5868318486317537
# ConsumerDefensive_time_decay 0.672464094027566 0.6707625090342777
# ConsumerCyclical_time_decay 0.6509741331084362 0.6523365321360952
# FinancialServices_time_decay 0.5015140334395481 0.500238023637098
# Healthcare_time_decay 0.5809653914079462 0.581134948555786
# Industrials 1.0 1.0
# BasicMaterials_time_decay 0.0 0.0
#
#
# 2024-10-15 14:00:08.115207529+00:00
# Technology_time_decay 0.6532917442547379 0.6544819482028588
# CommunicationServices_time_decay 0.6076597344330185 0.6074159025932784
# Energy_time_decay 0.5875078377087556 0.5868318486317537
# ConsumerDefensive_time_decay 0.636077220710671 0.6342345197775422
# ConsumerCyclical_time_decay 0.6670754529820725 0.6684341663058441
# FinancialServices_time_decay 0.5015140334395481 0.500238023637098
# Healthcare_time_decay 0.5809653914079463 0.581134948555786
# Industrials 1.0 1.0
# BasicMaterials_time_decay 0.0 0.0
#
#
# 2024-10-15 14:00:08.125207529+00:00
# Technology_time_decay 0.6507027767815907 0.6519025113434243
# CommunicationServices_time_decay 0.5633275674749944 0.5632611570282909
# Energy_time_decay 0.5875078377087555 0.5868318486317536
# ConsumerDefensive_time_decay 0.6360772207106709 0.6342345197775421
# ConsumerCyclical_time_decay 0.6670754529820725 0.6684341663058441
# FinancialServices_time_decay 0.501514033439548 0.5002380236370982
# Healthcare_time_decay 0.6340158832938337 0.6337339175069069
# Industrials 1.0 1.0
# BasicMaterials_time_decay 0.0 0.0
#
#
# 2024-10-15 14:00:08.128207529+00:00
# Technology_time_decay 0.6507027767815907 0.6519025113434243
# CommunicationServices_time_decay 0.5633275674749944 0.5632611570282909
# Energy_time_decay 0.5875078377087555 0.5868318486317536
# ConsumerDefensive_time_decay 0.6360772207106709 0.6342345197775421
# ConsumerCyclical_time_decay 0.6670754529820725 0.6684341663058441
# FinancialServices_time_decay 0.501514033439548 0.5002380236370982
# Healthcare_time_decay 0.6340158832938337 0.6337339175069069
# Industrials 1.0 1.0
# BasicMaterials_time_decay 0.0 0.0
#
#
# 2024-10-15 14:00:08.130207529+00:00
# Technology_time_decay 0.6507027767815907 0.6519025113434243
# CommunicationServices_time_decay 0.5633275674749944 0.5632611570282909
# Energy_time_decay 0.5875078377087555 0.5868318486317536
# ConsumerDefensive_time_decay 0.6360772207106709 0.6342345197775421
# ConsumerCyclical_time_decay 0.6670754529820725 0.6684341663058441
# FinancialServices_time_decay 0.501514033439548 0.5002380236370982
# Healthcare_time_decay 0.6340158832938337 0.6337339175069069
# Industrials 1.0 1.0
# BasicMaterials_time_decay 0.0 0.0
#
#
# 2024-10-15 14:00:08.135207529+00:00
# Technology_time_decay 0.654511361788218 0.6556167359326102
# CommunicationServices_time_decay 0.5687777599390822 0.568729838491449
# Energy_time_decay 0.6115452883727077 0.6106227136464607
# ConsumerDefensive_time_decay 0.6360772207106709 0.6342345197775421
# ConsumerCyclical_time_decay 0.6472324192549453 0.6485418873648127
# FinancialServices_time_decay 0.501514033439548 0.5002380236370982
# Healthcare_time_decay 0.6340158832938337 0.6337339175069069
# Industrials 1.0 1.0
# BasicMaterials_time_decay 0.0 0.0
#
#
# 2024-10-15 14:00:08.136207529+00:00
# Technology_time_decay 0.654511361788218 0.6556167359326102
# CommunicationServices_time_decay 0.5742264533573604 0.5740632600357094
# Energy_time_decay 0.6115452883727077 0.6106227136464607
# ConsumerDefensive_time_decay 0.6143589111752991 0.613217217127084
# ConsumerCyclical_time_decay 0.6472324192549453 0.6485418873648126
# FinancialServices_time_decay 0.501514033439548 0.5002380236370982
# Healthcare_time_decay 0.6340158832938337 0.6337339175069068
# Industrials 1.0 1.0
# BasicMaterials_time_decay 0.0 0.0
#
#
# 2024-10-15 14:00:08.140207529+00:00
# Technology_time_decay 0.6488188216895577 0.6498637018683255
# CommunicationServices_time_decay 0.5317416654933664 0.5313403770387937
# Energy_time_decay 0.6115452883727076 0.6106227136464607
# ConsumerDefensive_time_decay 0.6583604721487688 0.6575729999325525
# ConsumerCyclical_time_decay 0.6472324192549453 0.6485418873648126
# FinancialServices_time_decay 0.5015140334395481 0.5002380236370982
# Healthcare_time_decay 0.6340158832938338 0.6337339175069068
# Industrials 1.0 1.0
# BasicMaterials_time_decay 0.0 0.0
#
#
# 2024-10-15 14:00:08.144207529+00:00
# Technology_time_decay 0.6488188216895577 0.6498637018683256
# CommunicationServices_time_decay 0.5282058157418437 0.5278605385491707
# Energy_time_decay 0.6115452883727076 0.6106227136464608
# ConsumerDefensive_time_decay 0.6583604721487688 0.6575729999325525
# ConsumerCyclical_time_decay 0.6472324192549453 0.6485418873648126
# FinancialServices_time_decay 0.5015140334395481 0.5002380236370981
# Healthcare_time_decay 0.6340158832938338 0.6337339175069068
# Industrials 1.0 1.0
# BasicMaterials_time_decay 0.0 0.0
#
#
# 2024-10-15 14:00:08.145207529+00:00
# Technology_time_decay 0.6488188216895578 0.6498637018683256
# CommunicationServices_time_decay 0.5282058157418438 0.5278605385491707
# Energy_time_decay 0.6115452883727077 0.6106227136464608
# ConsumerDefensive_time_decay 0.6639763063571088 0.6633139323361029
# ConsumerCyclical_time_decay 0.6472324192549455 0.6485418873648126
# FinancialServices_time_decay 0.5015140334395481 0.5002380236370981
# Healthcare_time_decay 0.6340158832938337 0.6337339175069068
# Industrials 1.0 1.0
# BasicMaterials_time_decay 0.0 0.0
#
#
# 2024-10-15 14:00:08.150207529+00:00
# Technology_time_decay 0.642940210142734 0.643982136228334
# CommunicationServices_time_decay 0.5294091695211083 0.5290877379672738
# Energy_time_decay 0.6195117523673281 0.6185539284981254
# ConsumerDefensive_time_decay 0.6639763063571087 0.6633139323361029
# ConsumerCyclical_time_decay 0.6475770612877263 0.6487233649642875
# FinancialServices_time_decay 0.501514033439548 0.5002380236370981
# Healthcare_time_decay 0.6340158832938337 0.6337339175069068
# Industrials 1.0 1.0
# BasicMaterials_time_decay 0.0 0.0
#
#
# 2024-10-15 14:00:08.152207529+00:00
# Technology_time_decay 0.642940210142734 0.6439821362283339
# CommunicationServices_time_decay 0.5354509196230659 0.5349850567208146
# Energy_time_decay 0.6195117523673281 0.6185539284981254
# ConsumerDefensive_time_decay 0.6584983791973069 0.6580155386582168
# ConsumerCyclical_time_decay 0.6475770612877263 0.6487233649642875
# FinancialServices_time_decay 0.501514033439548 0.5002380236370981
# Healthcare_time_decay 0.6340158832938337 0.6337339175069068
# Industrials 1.0 1.0
# BasicMaterials_time_decay 0.0 0.0
#
#
# 2024-10-15 14:00:08.155207529+00:00
# Technology_time_decay 0.642940210142734 0.6439821362283339
# CommunicationServices_time_decay 0.5354509196230658 0.5349850567208146
# Energy_time_decay 0.6195117523673281 0.6185539284981254
# ConsumerDefensive_time_decay 0.6584983791973069 0.6580155386582168
# ConsumerCyclical_time_decay 0.6498643146508355 0.6507098547377972
# FinancialServices_time_decay 0.501514033439548 0.5002380236370981
# Healthcare_time_decay 0.6340158832938338 0.6337339175069068
# Industrials 1.0 1.0
# BasicMaterials_time_decay 0.0 0.0
#
#
# 2024-10-15 14:00:08.165207529+00:00
# Technology_time_decay 0.643615572761168 0.6446302878029402
# CommunicationServices_time_decay 0.5354509196230659 0.5349850567208145
# Energy_time_decay 0.6195117523673281 0.6185539284981254
# ConsumerDefensive_time_decay 0.6698082842767042 0.6691861485892435
# ConsumerCyclical_time_decay 0.6517718428200582 0.6525176522848717
# FinancialServices_time_decay 0.501514033439548 0.5002380236370981
# Healthcare_time_decay 0.621395265191998 0.6212176407635086
# Industrials 1.0 1.0
# BasicMaterials_time_decay 0.0 0.0
#
#
# 2024-10-15 14:00:08.168207529+00:00
# Technology_time_decay 0.6348167376283174 0.6359828630834966
# CommunicationServices_time_decay 0.5354509196230659 0.5349850567208145
# Energy_time_decay 0.6195117523673281 0.6185539284981254
# ConsumerDefensive_time_decay 0.6698082842767042 0.6691861485892435
# ConsumerCyclical_time_decay 0.6392260173058225 0.6402042679126722
# FinancialServices_time_decay 0.501514033439548 0.5002380236370982
# Healthcare_time_decay 0.621395265191998 0.6212176407635086
# Industrials 1.0 1.0
# BasicMaterials_time_decay 0.0 0.0
#
#
# 2024-10-15 14:00:08.170207529+00:00
# Technology_time_decay 0.6207968965671251 0.6216555900376088
# CommunicationServices_time_decay 0.5354509196230659 0.5349850567208145
# Energy_time_decay 0.6195117523673281 0.6185539284981254
# ConsumerDefensive_time_decay 0.6698082842767044 0.6691861485892435
# ConsumerCyclical_time_decay 0.6462387803216508 0.6472943335647419
# FinancialServices_time_decay 0.5015140334395481 0.5002380236370982
# Healthcare_time_decay 0.6165186208256939 0.6162435742994566
# Industrials 1.0 1.0
# BasicMaterials_time_decay 0.0 0.0
#
#
# 2024-10-15 14:00:08.175207529+00:00
# Technology_time_decay 0.605544304528753 0.6064489486256228
# CommunicationServices_time_decay 0.5354509196230659 0.5349850567208145
# Energy_time_decay 0.5861269840640598 0.5861658324316826
# ConsumerDefensive_time_decay 0.6698082842767042 0.6691861485892435
# ConsumerCyclical_time_decay 0.6428471413736997 0.6439199354560935
# FinancialServices_time_decay 0.5015140334395481 0.5002380236370982
# Healthcare_time_decay 0.5896120057589955 0.5894649800185753
# Industrials 1.0 1.0
# BasicMaterials_time_decay 0.0 0.0
#
#
# 2024-10-15 14:00:08.176207529+00:00
# Technology_time_decay 0.605544304528753 0.6064489486256228
# CommunicationServices_time_decay 0.5354509196230659 0.5349850567208145
# Energy_time_decay 0.60627449481023 0.6058754277987871
# ConsumerDefensive_time_decay 0.6698082842767042 0.6691861485892435
# ConsumerCyclical_time_decay 0.6428471413736997 0.6439199354560935
# FinancialServices_time_decay 0.5015140334395481 0.5002380236370982
# Healthcare_time_decay 0.5896120057589955 0.5894649800185753
# Industrials 1.0 1.0
# BasicMaterials_time_decay 0.0 0.0
#
#
# 2024-10-15 14:00:08.180207529+00:00
# Technology_time_decay 0.6055443045287531 0.6064489486256228
# CommunicationServices_time_decay 0.5354509196230659 0.5349850567208145
# Energy_time_decay 0.6095100246262953 0.6092190642408839
# ConsumerDefensive_time_decay 0.6698082842767044 0.6691861485892435
# ConsumerCyclical_time_decay 0.6371108890269147 0.6381308530467283
# FinancialServices_time_decay 0.501514033439548 0.5002380236370982
# Healthcare_time_decay 0.5896120057589956 0.5894649800185753
# Industrials 1.0 1.0
# BasicMaterials_time_decay 0.0 0.0
#
#
# 2024-10-15 14:00:08.184207529+00:00
# Technology_time_decay 0.6055443045287531 0.6064489486256228
# CommunicationServices_time_decay 0.5354509196230659 0.5349850567208146
# Energy_time_decay 0.6183054585291619 0.617948066398099
# ConsumerDefensive_time_decay 0.6698082842767044 0.6691861485892435
# ConsumerCyclical_time_decay 0.6371108890269147 0.6381308530467285
# FinancialServices_time_decay 0.501514033439548 0.5002380236370982
# Healthcare_time_decay 0.5896120057589956 0.5894649800185753
# Industrials 1.0 1.0
# BasicMaterials_time_decay 0.0 0.0
#
#
# 2024-10-15 14:00:08.185207529+00:00
# Technology_time_decay 0.605544304528753 0.6064489486256228
# CommunicationServices_time_decay 0.5354509196230659 0.5349850567208146
# Energy_time_decay 0.6194725858698279 0.6191812176083973
# ConsumerDefensive_time_decay 0.6698082842767042 0.6691861485892435
# ConsumerCyclical_time_decay 0.6371108890269148 0.6381308530467285
# FinancialServices_time_decay 0.501514033439548 0.5002380236370982
# Healthcare_time_decay 0.5896120057589956 0.5894649800185753
# Industrials 1.0 1.0
# BasicMaterials_time_decay 0.0 0.0
#
#
# 2024-10-15 14:00:08.190207529+00:00
# Technology_time_decay 0.588709623587914 0.5896054970678533
# CommunicationServices_time_decay 0.5354509196230659 0.5349850567208146
# Energy_time_decay 0.6248201120593755 0.6245608448134303
# ConsumerDefensive_time_decay 0.6698082842767044 0.6691861485892435
# ConsumerCyclical_time_decay 0.6371108890269147 0.6381308530467285
# FinancialServices_time_decay 0.501514033439548 0.5002380236370982
# Healthcare_time_decay 0.5896120057589955 0.5894649800185753
# Industrials 1.0 1.0
# BasicMaterials_time_decay 0.0 0.0
#
#
# 2024-10-15 14:00:08.192207529+00:00
# Technology_time_decay 0.6000915088773779 0.6008382082152763
# CommunicationServices_time_decay 0.5231455639382157 0.522985732955481
# Energy_time_decay 0.6219443690141154 0.6217477644063703
# ConsumerDefensive_time_decay 0.6698082842767044 0.6691861485892435
# ConsumerCyclical_time_decay 0.6371108890269147 0.6381308530467283
# FinancialServices_time_decay 0.501514033439548 0.5002380236370982
# Healthcare_time_decay 0.631901988321247 0.6318272146255342
# Industrials 1.0 1.0
# BasicMaterials_time_decay 0.0 0.0
#
#
# 2024-10-15 14:00:08.195207529+00:00
# Technology_time_decay 0.598031570608899 0.5984898020054257
# CommunicationServices_time_decay 0.5231455639382157 0.522985732955481
# Energy_time_decay 0.6236764034742567 0.6235127043475509
# ConsumerDefensive_time_decay 0.6698082842767042 0.6691861485892435
# ConsumerCyclical_time_decay 0.6389607655092212 0.6398942692246266
# FinancialServices_time_decay 0.5015140334395481 0.5002380236370982
# Healthcare_time_decay 0.607745632409308 0.6072454842888692
# Industrials 1.0 1.0
# BasicMaterials_time_decay 0.0 0.0
#
#
# 2024-10-15 14:00:08.205207529+00:00
# Technology_time_decay 0.5919600209879711 0.5924058554210592
# CommunicationServices_time_decay 0.5332577394250976 0.533109068737034
# Energy_time_decay 0.5824953202031103 0.5824096494593575
# ConsumerDefensive_time_decay 0.6510179418665369 0.6504447465771335
# ConsumerCyclical_time_decay 0.6342510273349082 0.6351764202703283
# FinancialServices_time_decay 0.501514033439548 0.5002380236370982
# Healthcare_time_decay 0.576750136834929 0.5763098688551214
# Industrials 1.0 1.0
# BasicMaterials_time_decay 0.0 0.0
#
#
# 2024-10-15 14:00:08.208207529+00:00
# Technology_time_decay 0.6003734727748768 0.6006148825658207
# CommunicationServices_time_decay 0.529121116361175 0.5290528747813105
# Energy_time_decay 0.5807305181901118 0.5806746458278161
# ConsumerDefensive_time_decay 0.6510179418665369 0.6504447465771334
# ConsumerCyclical_time_decay 0.6342510273349082 0.6351764202703282
# FinancialServices_time_decay 0.5415238168373536 0.5394972820132999
# Healthcare_time_decay 0.576750136834929 0.5763098688551214
# Industrials 1.0 1.0
# BasicMaterials_time_decay 0.0 0.0
#
#
# 2024-10-15 14:00:08.210207529+00:00
# Technology_time_decay 0.6003734727748768 0.6006148825658207
# CommunicationServices_time_decay 0.5291211163611751 0.5290528747813105
# Energy_time_decay 0.58602120546814 0.5860923464594662
# ConsumerDefensive_time_decay 0.6510179418665372 0.6504447465771334
# ConsumerCyclical_time_decay 0.6318633623825634 0.6327486407110547
# FinancialServices_time_decay 0.5415238168373536 0.5394972820132999
# Healthcare_time_decay 0.576750136834929 0.5763098688551214
# Industrials 1.0 1.0
# BasicMaterials_time_decay 0.0 0.0
#
#
# 2024-10-15 14:00:08.215207529+00:00
# Technology_time_decay 0.6003734727748767 0.6006148825658207
# CommunicationServices_time_decay 0.5239796537720557 0.5241375955975139
# Energy_time_decay 0.5839312261477415 0.5840052320563451
# ConsumerDefensive_time_decay 0.651017941866537 0.6504447465771334
# ConsumerCyclical_time_decay 0.6318633623825632 0.6327486407110547
# FinancialServices_time_decay 0.5415238168373536 0.5394972820132999
# Healthcare_time_decay 0.576750136834929 0.5763098688551214
# Industrials 1.0 1.0
# BasicMaterials_time_decay 0.0 0.0
#
#
# 2024-10-15 14:00:08.216207529+00:00
# Technology_time_decay 0.6003734727748767 0.6006148825658207
# CommunicationServices_time_decay 0.5295063940362318 0.529507349048129
# Energy_time_decay 0.5839312261477415 0.5840052320563451
# ConsumerDefensive_time_decay 0.651017941866537 0.6504447465771335
# ConsumerCyclical_time_decay 0.6318633623825632 0.6327486407110549
# FinancialServices_time_decay 0.5415238168373536 0.5394972820133
# Healthcare_time_decay 0.576750136834929 0.5763098688551214
# Industrials 1.0 1.0
# BasicMaterials_time_decay 0.0 0.0
#
#
# 2024-10-15 14:00:08.220207529+00:00
# Technology_time_decay 0.5993228688811703 0.5995535864816833
# CommunicationServices_time_decay 0.528672586017797 0.5286626985857384
# Energy_time_decay 0.5854471110828493 0.5855413819430456
# ConsumerDefensive_time_decay 0.651017941866537 0.6504447465771335
# ConsumerCyclical_time_decay 0.6318633623825632 0.6327486407110549
# FinancialServices_time_decay 0.5415238168373536 0.5394972820133
# Healthcare_time_decay 0.576750136834929 0.5763098688551214
# Industrials 1.0 1.0
# BasicMaterials_time_decay 0.0 0.0
#
#
# 2024-10-15 14:00:08.224207529+00:00
# Technology_time_decay 0.5993228688811703 0.5995535864816834
# CommunicationServices_time_decay 0.5320620873201081 0.5320117497940077
# Energy_time_decay 0.5854471110828493 0.5855413819430456
# ConsumerDefensive_time_decay 0.651017941866537 0.6504447465771336
# ConsumerCyclical_time_decay 0.6318633623825632 0.6327486407110549
# FinancialServices_time_decay 0.5415238168373536 0.5394972820132999
# Healthcare_time_decay 0.576750136834929 0.5763098688551214
# Industrials 1.0 1.0
# BasicMaterials_time_decay 0.0 0.0
#
#
# 2024-10-15 14:00:08.225207529+00:00
# Technology_time_decay 0.5993228688811703 0.5995535864816834
# CommunicationServices_time_decay 0.5354031862221319 0.5354473069080743
# Energy_time_decay 0.5854471110828494 0.5855413819430456
# ConsumerDefensive_time_decay 0.651017941866537 0.6504447465771336
# ConsumerCyclical_time_decay 0.6318633623825632 0.6327486407110549
# FinancialServices_time_decay 0.5415238168373537 0.5394972820132999
# Healthcare_time_decay 0.576750136834929 0.5763098688551214
# Industrials 1.0 1.0
# BasicMaterials_time_decay 0.0 0.0
#
#
# 2024-10-15 14:00:08.230207529+00:00
# Technology_time_decay 0.5993228688811703 0.5995535864816834
# CommunicationServices_time_decay 0.5354031862221319 0.5354473069080743
# Energy_time_decay 0.5854471110828494 0.5855413819430456
# ConsumerDefensive_time_decay 0.651017941866537 0.6504447465771336
# ConsumerCyclical_time_decay 0.6318633623825632 0.6327486407110549
# FinancialServices_time_decay 0.5415238168373537 0.5394972820132999
# Healthcare_time_decay 0.576750136834929 0.5763098688551214
# Industrials 1.0 1.0
# BasicMaterials_time_decay 0.0 0.0
#
#
# 2024-10-15 14:00:08.232207529+00:00
# Technology_time_decay 0.595960999772828 0.5962804274312082
# CommunicationServices_time_decay 0.5354031862221319 0.5354473069080744
# Energy_time_decay 0.5854471110828494 0.5855413819430456
# ConsumerDefensive_time_decay 0.651017941866537 0.6504447465771336
# ConsumerCyclical_time_decay 0.6318633623825632 0.6327486407110547
# FinancialServices_time_decay 0.5415238168373537 0.5394972820132999
# Healthcare_time_decay 0.576750136834929 0.5763098688551214
# Industrials 1.0 1.0
# BasicMaterials_time_decay 0.0 0.0
#
#
# 2024-10-15 14:00:08.235207529+00:00
# Technology_time_decay 0.595960999772828 0.5962804274312082
# CommunicationServices_time_decay 0.5354031862221319 0.5354473069080744
# Energy_time_decay 0.5854471110828494 0.5855413819430456
# ConsumerDefensive_time_decay 0.651017941866537 0.6504447465771336
# ConsumerCyclical_time_decay 0.6318633623825632 0.6327486407110547
# FinancialServices_time_decay 0.5415238168373537 0.5394972820132999
# Healthcare_time_decay 0.576750136834929 0.5763098688551214
# Industrials 1.0 1.0
# BasicMaterials_time_decay 0.0 0.0
#
#
# 2024-10-15 14:00:08.245207529+00:00
# Technology_time_decay 0.6291849618365526 0.6292557867868346
# CommunicationServices_time_decay 0.5389514886041765 0.5389699099713819
# Energy_time_decay 0.5807701267735667 0.5808939079364385
# ConsumerDefensive_time_decay 0.651017941866537 0.6504447465771335
# ConsumerCyclical_time_decay 0.6355392698655904 0.6362839097302185
# FinancialServices_time_decay 0.5415238168373536 0.5394972820132999
# Healthcare_time_decay 0.5767501368349289 0.5763098688551214
# Industrials 1.0 1.0
# BasicMaterials_time_decay 0.0 0.0
#
#
# 2024-10-15 14:00:08.248207529+00:00
# Technology_time_decay 0.6341870796669753 0.6341734067211686
# CommunicationServices_time_decay 0.5389514886041765 0.538969909971382
# Energy_time_decay 0.5807701267735667 0.5808939079364385
# ConsumerDefensive_time_decay 0.651017941866537 0.6504447465771335
# ConsumerCyclical_time_decay 0.6355392698655904 0.6362839097302184
# FinancialServices_time_decay 0.5415238168373536 0.5394972820132999
# Healthcare_time_decay 0.5767501368349289 0.5763098688551213
# Industrials 1.0 1.0
# BasicMaterials_time_decay 0.0 0.0
#
#
# 2024-10-15 14:00:08.250207529+00:00
# Technology_time_decay 0.6307721566638603 0.6306888741524194
# CommunicationServices_time_decay 0.5346587313945182 0.5345786939819034
# Energy_time_decay 0.5807701267735667 0.5808939079364385
# ConsumerDefensive_time_decay 0.651017941866537 0.6504447465771335
# ConsumerCyclical_time_decay 0.6352522537081019 0.6359375898588939
# FinancialServices_time_decay 0.5415238168373536 0.5394972820132999
# Healthcare_time_decay 0.5767501368349289 0.5763098688551213
# Industrials 1.0 1.0
# BasicMaterials_time_decay 0.0 0.0
#
#
# 2024-10-15 14:00:08.255207529+00:00
# Technology_time_decay 0.6366356488472495 0.6365652699179111
# CommunicationServices_time_decay 0.5252546010901814 0.5251994091883128
# Energy_time_decay 0.5807701267735667 0.5808939079364385
# ConsumerDefensive_time_decay 0.651017941866537 0.6504447465771335
# ConsumerCyclical_time_decay 0.6380831154946018 0.6387367096550347
# FinancialServices_time_decay 0.5415238168373537 0.5394972820132999
# Healthcare_time_decay 0.5767501368349289 0.5763098688551214
# Industrials 1.0 1.0
# BasicMaterials_time_decay 0.0 0.0
#
#
# 2024-10-15 14:00:08.256207529+00:00
# Technology_time_decay 0.6366356488472495 0.6365652699179111
# CommunicationServices_time_decay 0.5252546010901814 0.5251994091883128
# Energy_time_decay 0.5807701267735667 0.5808939079364385
# ConsumerDefensive_time_decay 0.651017941866537 0.6504447465771335
# ConsumerCyclical_time_decay 0.6380831154946018 0.6387367096550347
# FinancialServices_time_decay 0.5415238168373537 0.5394972820132999
# Healthcare_time_decay 0.5767501368349289 0.5763098688551214
# Industrials 1.0 1.0
# BasicMaterials_time_decay 0.0 0.0
#
#
# 2024-10-15 14:00:08.260207529+00:00
# Technology_time_decay 0.6432944879313968 0.6433149108467318
# CommunicationServices_time_decay 0.5252546010901814 0.5251994091883128
# Energy_time_decay 0.5807701267735667 0.5808939079364385
# ConsumerDefensive_time_decay 0.651017941866537 0.6504447465771335
# ConsumerCyclical_time_decay 0.6380831154946017 0.6387367096550347
# FinancialServices_time_decay 0.5415238168373537 0.5394972820132999
# Healthcare_time_decay 0.576750136834929 0.5763098688551214
# Industrials 1.0 1.0
# BasicMaterials_time_decay 0.0 0.0
#
#
# 2024-10-15 14:00:08.264207529+00:00
# Technology_time_decay 0.6441616974409898 0.6441714803506962
# CommunicationServices_time_decay 0.4969354414141411 0.4971974520431706
# Energy_time_decay 0.5870542210507294 0.5871000537776987
# ConsumerDefensive_time_decay 0.651017941866537 0.6504447465771335
# ConsumerCyclical_time_decay 0.6380831154946017 0.6387367096550347
# FinancialServices_time_decay 0.5415238168373537 0.5394972820132999
# Healthcare_time_decay 0.5767501368349289 0.5763098688551213
# Industrials 1.0 1.0
# BasicMaterials_time_decay 0.0 0.0
#
#
# 2024-10-15 14:00:08.265207529+00:00
# Technology_time_decay 0.6441616974409898 0.6441714803506962
# CommunicationServices_time_decay 0.4969354414141411 0.4971974520431706
# Energy_time_decay 0.5870542210507294 0.5871000537776987
# ConsumerDefensive_time_decay 0.651017941866537 0.6504447465771335
# ConsumerCyclical_time_decay 0.6380831154946017 0.6387367096550347
# FinancialServices_time_decay 0.5415238168373537 0.5394972820132999
# Healthcare_time_decay 0.5767501368349289 0.5763098688551213
# Industrials 1.0 1.0
# BasicMaterials_time_decay 0.0 0.0
#
#
# 2024-10-15 14:00:08.270207529+00:00
# Technology_time_decay 0.6429968420566632 0.6430024961398296
# CommunicationServices_time_decay 0.4969354414141411 0.4971974520431706
# Energy_time_decay 0.5929475045247633 0.5930203507954651
# ConsumerDefensive_time_decay 0.6510179418665372 0.6504447465771335
# ConsumerCyclical_time_decay 0.6380831154946017 0.6387367096550347
# FinancialServices_time_decay 0.5415238168373537 0.5394972820132999
# Healthcare_time_decay 0.5824949988658146 0.5820792523012689
# Industrials 1.0 1.0
# BasicMaterials_time_decay 0.0 0.0
#
#
# 2024-10-15 14:00:08.272207529+00:00
# Technology_time_decay 0.6429968420566632 0.6430024961398296
# CommunicationServices_time_decay 0.5008173742194696 0.5009970534156086
# Energy_time_decay 0.5929475045247633 0.5930203507954651
# ConsumerDefensive_time_decay 0.6510179418665372 0.6504447465771336
# ConsumerCyclical_time_decay 0.6380831154946017 0.6387367096550347
# FinancialServices_time_decay 0.5415238168373537 0.5394972820132999
# Healthcare_time_decay 0.5824949988658146 0.5820792523012688
# Industrials 1.0 1.0
# BasicMaterials_time_decay 0.0 0.0
#
#
# 2024-10-15 14:00:08.275207529+00:00
# Technology_time_decay 0.6429968420566632 0.6430024961398296
# CommunicationServices_time_decay 0.5046398553763066 0.5048912100517111
# Energy_time_decay 0.5929475045247633 0.5930203507954651
# ConsumerDefensive_time_decay 0.651017941866537 0.6504447465771336
# ConsumerCyclical_time_decay 0.6380831154946017 0.6387367096550347
# FinancialServices_time_decay 0.5415238168373537 0.5394972820132999
# Healthcare_time_decay 0.5824949988658146 0.5820792523012688
# Industrials 1.0 1.0
# BasicMaterials_time_decay 0.0 0.0
#
#
# 2024-10-15 14:00:08.285207529+00:00
# Technology_time_decay 0.6577560228915026 0.6577174999052231
# CommunicationServices_time_decay 0.5084987961348023 0.508725058303417
# Energy_time_decay 0.5929475045247633 0.5930203507954651
# ConsumerDefensive_time_decay 0.6510179418665372 0.6504447465771335
# ConsumerCyclical_time_decay 0.6346150080138606 0.6351934384007445
# FinancialServices_time_decay 0.5415238168373536 0.5394972820132999
# Healthcare_time_decay 0.5824949988658146 0.5820792523012689
# Industrials 1.0 1.0
# BasicMaterials_time_decay 0.0 0.0
#
#
# 2024-10-15 14:00:08.288207529+00:00
# Technology_time_decay 0.6599716227989038 0.6598992830971144
# CommunicationServices_time_decay 0.5084987961348023 0.508725058303417
# Energy_time_decay 0.5929475045247634 0.5930203507954651
# ConsumerDefensive_time_decay 0.6510179418665372 0.6504447465771335
# ConsumerCyclical_time_decay 0.6320208309974807 0.6326593967664299
# FinancialServices_time_decay 0.5415238168373537 0.5394972820132999
# Healthcare_time_decay 0.5824949988658146 0.5820792523012689
# Industrials 1.0 1.0
# BasicMaterials_time_decay 0.0 0.0
#
#
# 2024-10-15 14:00:08.290207529+00:00
# Technology_time_decay 0.6599716227989038 0.6598992830971144
# CommunicationServices_time_decay 0.5084987961348023 0.508725058303417
# Energy_time_decay 0.5929475045247634 0.5930203507954651
# ConsumerDefensive_time_decay 0.6510179418665372 0.6504447465771335
# ConsumerCyclical_time_decay 0.6320208309974807 0.6326593967664299
# FinancialServices_time_decay 0.5415238168373537 0.5394972820132999
# Healthcare_time_decay 0.5824949988658146 0.5820792523012689
# Industrials 1.0 1.0
# BasicMaterials_time_decay 0.0 0.0
#
#
# 2024-10-15 14:00:08.295207529+00:00
# Technology_time_decay 0.657582789338481 0.6575144599762581
# CommunicationServices_time_decay 0.5084987961348024 0.508725058303417
# Energy_time_decay 0.5984274618854803 0.5984964941207784
# ConsumerDefensive_time_decay 0.6510179418665372 0.6504447465771335
# ...
# Energy_time_decay 0.5914317703501369 0.5923965114238815
# ConsumerDefensive_time_decay 0.660016964677976 0.6600120691240942
# ConsumerCyclical_time_decay 0.6282196632275302 0.6279246104382423
# FinancialServices_time_decay 0.5595328418548587 0.5588554517789588
# Healthcare_time_decay 0.6429337377570836 0.6427457295512307
# Industrials 0.5339783372241765 0.5321656431989108
# BasicMaterials_time_decay 0.4656315614625521 0.4657494202603572
#
#
# 2024-10-15 14:00:10.905207529+00:00
# Technology_time_decay 0.6430272007125926 0.6429395716232894
# CommunicationServices_time_decay 0.6023607147569563 0.6021726472948413
# Energy_time_decay 0.5914317703501369 0.5923965114238815
# ConsumerDefensive_time_decay 0.6600169646779759 0.6600120691240942
# ConsumerCyclical_time_decay 0.6282196632275303 0.6279246104382423
# FinancialServices_time_decay 0.5654112068873955 0.5648884780049372
# Healthcare_time_decay 0.6429337377570836 0.6427457295512307
# Industrials 0.5339783372241765 0.5321656431989108
# BasicMaterials_time_decay 0.465631561462552 0.4657494202603572
#
#
# 2024-10-15 14:00:10.910207529+00:00
# Technology_time_decay 0.6416245753878602 0.6415326641876712
# CommunicationServices_time_decay 0.6023607147569563 0.6021726472948413
# Energy_time_decay 0.5973376611434752 0.5982726106137572
# ConsumerDefensive_time_decay 0.6601676469676552 0.6601631594572712
# ConsumerCyclical_time_decay 0.6310631416358966 0.6307680654096147
# FinancialServices_time_decay 0.5654112068873955 0.5648884780049372
# Healthcare_time_decay 0.6198050900198607 0.619609481309187
# Industrials 0.5339783372241765 0.5321656431989108
# BasicMaterials_time_decay 0.4828566260190041 0.4830317940479532
#
#
# 2024-10-15 14:00:10.912207529+00:00
# Technology_time_decay 0.6407410895236348 0.6406682132583317
# CommunicationServices_time_decay 0.6039964546378748 0.6037749111492882
# Energy_time_decay 0.5805376088709246 0.5817491980021504
# ConsumerDefensive_time_decay 0.6601676469676552 0.6601631594572712
# ConsumerCyclical_time_decay 0.6310631416358966 0.6307680654096147
# FinancialServices_time_decay 0.5575882329045789 0.5572673735549408
# Healthcare_time_decay 0.6296862600664355 0.6292862853016533
# Industrials 0.5339783372241765 0.5321656431989108
# BasicMaterials_time_decay 0.5087220855727619 0.5084485821161426
#
#
# 2024-10-15 14:00:10.915207529+00:00
# Technology_time_decay 0.6415865770409324 0.6415306999777303
# CommunicationServices_time_decay 0.6048092883186196 0.6046036434699537
# Energy_time_decay 0.5832610682271328 0.5845176484456946
# ConsumerDefensive_time_decay 0.6550942343549876 0.6550036364479681
# ConsumerCyclical_time_decay 0.6299170927986091 0.6296067752783873
# FinancialServices_time_decay 0.5575882329045789 0.5572673735549408
# Healthcare_time_decay 0.6310904180038429 0.6307430641081782
# Industrials 0.5339783372241765 0.5321656431989108
# BasicMaterials_time_decay 0.5087220855727618 0.5084485821161426
#
#
# 2024-10-15 14:00:10.925207529+00:00
# Technology_time_decay 0.6409347519134708 0.6409048678659279
# CommunicationServices_time_decay 0.6031060339774488 0.6029121151763245
# Energy_time_decay 0.6046259923705763 0.6059260659967648
# ConsumerDefensive_time_decay 0.6550942343549876 0.6550036364479681
# ConsumerCyclical_time_decay 0.6303231305131465 0.630011682317152
# FinancialServices_time_decay 0.5575882329045788 0.5572673735549407
# Healthcare_time_decay 0.6279025172785213 0.6275492078922926
# Industrials 0.5339783372241765 0.5321656431989108
# BasicMaterials_time_decay 0.5087220855727619 0.5084485821161426
#
#
# 2024-10-15 14:00:10.928207529+00:00
# Technology_time_decay 0.6409347519134708 0.6409048678659279
# CommunicationServices_time_decay 0.6039767225826453 0.6037693031705
# Energy_time_decay 0.6071516324472397 0.6084027366159995
# ConsumerDefensive_time_decay 0.6760014254692202 0.6756714135296288
# ConsumerCyclical_time_decay 0.6310373972618524 0.630711585277914
# FinancialServices_time_decay 0.5575882329045788 0.5572673735549407
# Healthcare_time_decay 0.6401336327586767 0.6395895954289338
# Industrials 0.5339783372241765 0.5321656431989109
# BasicMaterials_time_decay 0.5087220855727619 0.5084485821161426
#
#
# 2024-10-15 14:00:10.930207529+00:00
# Technology_time_decay 0.6387987915772912 0.6387192641021721
# CommunicationServices_time_decay 0.6039767225826453 0.6037693031705
# Energy_time_decay 0.6071516324472397 0.6084027366159995
# ConsumerDefensive_time_decay 0.6584158601638531 0.6577519650299501
# ConsumerCyclical_time_decay 0.6310373972618525 0.630711585277914
# FinancialServices_time_decay 0.5640892005208769 0.563901089027211
# Healthcare_time_decay 0.6413993962445181 0.6408867405183919
# Industrials 0.5339783372241765 0.5321656431989109
# BasicMaterials_time_decay 0.5087220855727619 0.5084485821161426
#
#
# 2024-10-15 14:00:10.935207529+00:00
# Technology_time_decay 0.6378911851984691 0.6378136628226817
# CommunicationServices_time_decay 0.6035110691722035 0.603305094347456
# Energy_time_decay 0.6071516324472397 0.6084027366159995
# ConsumerDefensive_time_decay 0.6584158601638531 0.6577519650299501
# ConsumerCyclical_time_decay 0.6310373972618525 0.630711585277914
# FinancialServices_time_decay 0.5640892005208767 0.563901089027211
# Healthcare_time_decay 0.6413993962445182 0.6408867405183919
# Industrials 0.5339783372241765 0.5321656431989109
# BasicMaterials_time_decay 0.5087220855727619 0.5084485821161426
#
#
# 2024-10-15 14:00:10.936207529+00:00
# Technology_time_decay 0.6378911851984691 0.6378136628226817
# CommunicationServices_time_decay 0.6035110691722035 0.603305094347456
# Energy_time_decay 0.6071516324472397 0.6084027366159996
# ConsumerDefensive_time_decay 0.6603098260298713 0.6596257783154443
# ConsumerCyclical_time_decay 0.6310373972618525 0.630711585277914
# FinancialServices_time_decay 0.5640892005208767 0.563901089027211
# Healthcare_time_decay 0.6413993962445182 0.6408867405183919
# Industrials 0.5339783372241765 0.5321656431989109
# BasicMaterials_time_decay 0.5087220855727619 0.5084485821161426
#
#
# 2024-10-15 14:00:10.940207529+00:00
# Technology_time_decay 0.6377710396011826 0.63770906024505
# CommunicationServices_time_decay 0.6044192857234002 0.6042264630594706
# Energy_time_decay 0.6071516324472397 0.6084027366159996
# ConsumerDefensive_time_decay 0.6603098260298712 0.6596257783154443
# ConsumerCyclical_time_decay 0.631364219769593 0.6310503166737526
# FinancialServices_time_decay 0.5771533018238244 0.5770916651965516
# Healthcare_time_decay 0.6413993962445182 0.6408867405183919
# Industrials 0.5339783372241765 0.5321656431989109
# BasicMaterials_time_decay 0.5087220855727619 0.5084485821161426
#
#
# 2024-10-15 14:00:10.944207529+00:00
# Technology_time_decay 0.6383202248471381 0.6382521635183658
# CommunicationServices_time_decay 0.6044192857234002 0.6042264630594707
# Energy_time_decay 0.5962881605768415 0.597607290643359
# ConsumerDefensive_time_decay 0.6570473235212809 0.6564085796035432
# ConsumerCyclical_time_decay 0.631364219769593 0.6310503166737526
# FinancialServices_time_decay 0.5771533018238244 0.5770916651965515
# Healthcare_time_decay 0.64033529947365 0.6398390765864966
# Industrials 0.5339783372241765 0.5321656431989109
# BasicMaterials_time_decay 0.579330867138094 0.5787446054896899
#
#
# 2024-10-15 14:00:10.945207529+00:00
# Technology_time_decay 0.6386906967102365 0.6386332367240922
# CommunicationServices_time_decay 0.6044192857234001 0.6042264630594707
# Energy_time_decay 0.5962881605768415 0.597607290643359
# ConsumerDefensive_time_decay 0.657047323521281 0.6564085796035432
# ConsumerCyclical_time_decay 0.631364219769593 0.6310503166737526
# FinancialServices_time_decay 0.5771533018238244 0.5770916651965515
# Healthcare_time_decay 0.64033529947365 0.6398390765864966
# Industrials 0.5339783372241765 0.5321656431989109
# BasicMaterials_time_decay 0.579330867138094 0.5787446054896899
#
#
# 2024-10-15 14:00:10.950207529+00:00
# Technology_time_decay 0.6383999902426174 0.6383417721331474
# CommunicationServices_time_decay 0.6038821552093631 0.6037249729450058
# Energy_time_decay 0.5962881605768415 0.597607290643359
# ConsumerDefensive_time_decay 0.6570473235212809 0.6564085796035432
# ConsumerCyclical_time_decay 0.631364219769593 0.6310503166737526
# FinancialServices_time_decay 0.565934984979346 0.5661000112984496
# Healthcare_time_decay 0.64033529947365 0.6398390765864966
# Industrials 0.5339783372241765 0.5321656431989109
# BasicMaterials_time_decay 0.579330867138094 0.5787446054896899
#
#
# 2024-10-15 14:00:10.952207529+00:00
# Technology_time_decay 0.6387881379327113 0.6387215507415048
# CommunicationServices_time_decay 0.6038821552093631 0.6037249729450057
# Energy_time_decay 0.5962881605768415 0.597607290643359
# ConsumerDefensive_time_decay 0.6520804186961797 0.6515622453000092
# ConsumerCyclical_time_decay 0.6321473294762587 0.631813712501999
# FinancialServices_time_decay 0.565934984979346 0.5661000112984496
# Healthcare_time_decay 0.64033529947365 0.6398390765864966
# Industrials 0.5339783372241765 0.5321656431989109
# BasicMaterials_time_decay 0.579330867138094 0.5787446054896899
#
#
# 2024-10-15 14:00:10.955207529+00:00
# Technology_time_decay 0.6387881379327113 0.6387215507415048
# CommunicationServices_time_decay 0.6038821552093631 0.6037249729450057
# Energy_time_decay 0.5962881605768415 0.597607290643359
# ConsumerDefensive_time_decay 0.6475524765620378 0.6469729161651124
# ConsumerCyclical_time_decay 0.6315882516942781 0.631248412601353
# FinancialServices_time_decay 0.5659349849793461 0.5661000112984496
# Healthcare_time_decay 0.6403352994736499 0.6398390765864966
# Industrials 0.5339783372241765 0.5321656431989109
# BasicMaterials_time_decay 0.579330867138094 0.5787446054896899
#
#
# 2024-10-15 14:00:10.965207529+00:00
# Technology_time_decay 0.6403115889226647 0.6402116425289087
# CommunicationServices_time_decay 0.6023646318985855 0.6022170482968695
# Energy_time_decay 0.599145191385118 0.6004385202592152
# ConsumerDefensive_time_decay 0.649336597925437 0.6487455894944796
# ConsumerCyclical_time_decay 0.6209756333350389 0.6207434626598503
# FinancialServices_time_decay 0.5659349849793461 0.5661000112984496
# Healthcare_time_decay 0.6403352994736499 0.6398390765864965
# Industrials 0.5339783372241765 0.5321656431989109
# BasicMaterials_time_decay 0.5793308671380939 0.5787446054896899
#
#
# 2024-10-15 14:00:10.968207529+00:00
# Technology_time_decay 0.6417144578959605 0.6415930943960121
# CommunicationServices_time_decay 0.6023646318985855 0.6022170482968695
# Energy_time_decay 0.599145191385118 0.6004385202592152
# ConsumerDefensive_time_decay 0.649336597925437 0.6487455894944797
# ConsumerCyclical_time_decay 0.6204620300713012 0.6202413338615087
# FinancialServices_time_decay 0.5659349849793461 0.5661000112984496
# Healthcare_time_decay 0.6403352994736499 0.6398390765864966
# Industrials 0.5339783372241765 0.5321656431989109
# BasicMaterials_time_decay 0.5793308671380939 0.5787446054896899
#
#
# 2024-10-15 14:00:10.970207529+00:00
# Technology_time_decay 0.6417144578959605 0.6415930943960121
# CommunicationServices_time_decay 0.6023646318985855 0.6022170482968695
# Energy_time_decay 0.5991451913851181 0.6004385202592152
# ConsumerDefensive_time_decay 0.649336597925437 0.6487455894944797
# ConsumerCyclical_time_decay 0.6212659895897295 0.6210614257914612
# FinancialServices_time_decay 0.5659349849793461 0.5661000112984496
# Healthcare_time_decay 0.6403352994736499 0.6398390765864966
# Industrials 0.5339783372241766 0.5321656431989109
# BasicMaterials_time_decay 0.579330867138094 0.5787446054896899
#
#
# 2024-10-15 14:00:10.975207529+00:00
# Technology_time_decay 0.6392647023793857 0.6391528561065749
# CommunicationServices_time_decay 0.6095840260622473 0.6094797047520351
# Energy_time_decay 0.5991451913851181 0.6004385202592152
# ConsumerDefensive_time_decay 0.6493365979254371 0.6487455894944797
# ConsumerCyclical_time_decay 0.6163883191327674 0.6162170952773613
# FinancialServices_time_decay 0.5659349849793461 0.5661000112984496
# Healthcare_time_decay 0.6419007982352354 0.6414037240655511
# Industrials 0.5339783372241766 0.5321656431989109
# BasicMaterials_time_decay 0.579330867138094 0.5787446054896899
#
#
# 2024-10-15 14:00:10.976207529+00:00
# Technology_time_decay 0.6385876722163509 0.6384934481227376
# CommunicationServices_time_decay 0.6022969408869836 0.602357280810652
# Energy_time_decay 0.5991451913851181 0.6004385202592151
# ConsumerDefensive_time_decay 0.6493365979254371 0.6487455894944797
# ConsumerCyclical_time_decay 0.6163883191327674 0.6162170952773613
# FinancialServices_time_decay 0.5659349849793461 0.5661000112984496
# Healthcare_time_decay 0.6419007982352354 0.6414037240655511
# Industrials 0.5339783372241766 0.5321656431989109
# BasicMaterials_time_decay 0.579330867138094 0.5787446054896898
#
#
# 2024-10-15 14:00:10.980207529+00:00
# Technology_time_decay 0.6379120745894935 0.6378085719888013
# CommunicationServices_time_decay 0.6115238996855713 0.6116981885757428
# Energy_time_decay 0.5991451913851181 0.6004385202592151
# ConsumerDefensive_time_decay 0.6493365979254371 0.6487455894944797
# ConsumerCyclical_time_decay 0.6158884671073305 0.6157132522392402
# FinancialServices_time_decay 0.5659349849793461 0.5661000112984496
# Healthcare_time_decay 0.6419007982352353 0.6414037240655511
# Industrials 0.5339783372241766 0.5321656431989109
# BasicMaterials_time_decay 0.579330867138094 0.5787446054896898
#
#
# 2024-10-15 14:00:10.984207529+00:00
# Technology_time_decay 0.6386959157860865 0.6385839135455894
# CommunicationServices_time_decay 0.6118117877617353 0.6119406516155976
# Energy_time_decay 0.5991451913851181 0.6004385202592152
# ConsumerDefensive_time_decay 0.6493365979254371 0.6487455894944796
# ConsumerCyclical_time_decay 0.6247199611951717 0.624433125896664
# FinancialServices_time_decay 0.5659349849793461 0.5661000112984496
# Healthcare_time_decay 0.6419007982352353 0.641403724065551
# Industrials 0.5339783372241766 0.5321656431989109
# BasicMaterials_time_decay 0.579330867138094 0.5787446054896899
#
#
# 2024-10-15 14:00:10.985207529+00:00
# Technology_time_decay 0.6386959157860865 0.6385839135455894
# CommunicationServices_time_decay 0.6118696809699576 0.6119813296434731
# Energy_time_decay 0.5991451913851181 0.6004385202592152
# ConsumerDefensive_time_decay 0.6493365979254371 0.6487455894944796
# ConsumerCyclical_time_decay 0.6219804175190814 0.6216274576201971
# FinancialServices_time_decay 0.5659349849793461 0.5661000112984496
# Healthcare_time_decay 0.6419007982352353 0.641403724065551
# Industrials 0.5339783372241766 0.5321656431989109
# BasicMaterials_time_decay 0.5793308671380939 0.5787446054896899
#
#
# 2024-10-15 14:00:10.990207529+00:00
# Technology_time_decay 0.6398948415080336 0.6397877758442274
# CommunicationServices_time_decay 0.6116324638690958 0.6117412422858168
# Energy_time_decay 0.5991451913851181 0.6004385202592152
# ConsumerDefensive_time_decay 0.6493365979254371 0.6487455894944796
# ConsumerCyclical_time_decay 0.6207105982315014 0.6203579622288439
# FinancialServices_time_decay 0.5739576566696735 0.5739222708720038
# Healthcare_time_decay 0.6405816715332217 0.6400852044212376
# Industrials 0.5339783372241765 0.5321656431989109
# BasicMaterials_time_decay 0.579330867138094 0.5787446054896898
#
#
# 2024-10-15 14:00:10.992207529+00:00
# Technology_time_decay 0.6398948415080336 0.6397877758442274
# CommunicationServices_time_decay 0.6116324638690958 0.6117412422858168
# Energy_time_decay 0.5991451913851181 0.6004385202592152
# ConsumerDefensive_time_decay 0.6493365979254371 0.6487455894944796
# ConsumerCyclical_time_decay 0.6207105982315014 0.6203579622288439
# FinancialServices_time_decay 0.5739576566696735 0.5739222708720038
# Healthcare_time_decay 0.6405816715332217 0.6400852044212376
# Industrials 0.5339783372241765 0.5321656431989109
# BasicMaterials_time_decay 0.579330867138094 0.5787446054896898
#
#
# 2024-10-15 14:00:10.995207529+00:00
# Technology_time_decay 0.6398948415080336 0.6397877758442274
# CommunicationServices_time_decay 0.6116324638690958 0.6117412422858168
# Energy_time_decay 0.5991451913851181 0.6004385202592152
# ConsumerDefensive_time_decay 0.6493365979254371 0.6487455894944796
# ConsumerCyclical_time_decay 0.6207105982315014 0.6203579622288439
# FinancialServices_time_decay 0.5739576566696735 0.5739222708720038
# Healthcare_time_decay 0.6405816715332217 0.6400852044212376
# Industrials 0.5339783372241765 0.5321656431989109
# BasicMaterials_time_decay 0.579330867138094 0.5787446054896898

# %%
for column in accuracy_fixed_window1.columns:
    if column not in ["check_points", "window_reset"]:
        comparison_df[column + "_match"] = comparison_df[column + "_200"] == comparison_df[column + "_800"]
        

# Separate out mismatches for further analysis if needed
mismatches = comparison_df[comparison_df['reset_match'] == False]
print("Mismatches:")
print(mismatches)
